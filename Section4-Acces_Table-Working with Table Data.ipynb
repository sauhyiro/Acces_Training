# %% [markdown]
# ## **Conceptos Fundamentales al Trabajar con Tablas en Access (Datasheet View)**
#
# En esta lección, el instructor regresa al objeto más importante de Access: **las tablas**, para explicar conceptos fundamentales que necesitas dominar cuando **mantienes, editas o actualizas datos** dentro de ellas.
#
# ### 🔑 ¿Qué quiere enseñar esta lección?
# - Cómo interactuar con una tabla en **Datasheet View**.
# - Cómo **editar, agregar o eliminar** registros.
# - Cómo Access **guarda automáticamente** los cambios.
# - Cómo identificar cuándo un registro está siendo editado.
# - Cómo **evitar perder información accidentalmente**.
# - Cómo utilizar herramientas básicas de navegación dentro de la tabla.
#
# ---
#
# ## 📋 Datasheet View: El modo principal para editar datos
#
# La **vista de hoja de datos** (Datasheet View):
#
# - Muestra el contenido de la tabla como una grilla similar a Excel.
# - Permite:
#   - Editar valores
#   - Agregar registros
#   - Eliminar registros
#   - Navegar entre filas
# - Es la vista más directa y común para tareas de mantenimiento de datos.
#
# ---
#
# ## ✏️ Editar registros
# - Solo necesitas hacer clic en un campo y cambiar su valor.
#   Ejemplo: actualizar un contacto de “Maria Anders” a “Fred Weasley”.
# - Cuando un registro está siendo modificado, aparece un **icono de lápiz** en el selector de fila.
# - Esto indica que el registro está actualmente **en edición**.
#
# ---
#
# ## 💾 Guardado automático (MUY IMPORTANTE)
# Access **guarda los cambios automáticamente** cuando:
# - Abandonas la fila (por clic o con las flechas).
# - Te mueves a un nuevo registro.
#
# No necesitas:
# - Presionar *Ctrl + S*
# - Usar *Save* en el menú
# - Ir a *File → Save*
#
# ➜ En cuanto el lápiz desaparece, el registro ya fue guardado.
#
# ---
#
# ## 🗑 Eliminar registros (sin posibilidad de deshacer)
# Eliminar es simple, pero también **peligroso**, porque no hay “Undo” después de confirmar.
#
# Pasos:
# 1. Seleccionar la fila.
# 2. Presionar la tecla **Delete**.
# 3. Confirmar cuando Access pregunta:
#
# > *“You are about to delete X records. You won’t be able to undo this.”*
#
# Si confirmas:
# - Los registros se eliminan **permanentemente**.
#
# ---
#
# ## ➕ Agregar nuevos registros
# Se pueden agregar de dos formas:
#
# ### 1. Con el botón **New Record** (icono de estrella ✱)
# - Te lleva a la última fila en blanco.
# - Ideal para captura continua.
#
# ### 2. Escribiendo directamente en la fila con asterisco
# - Access crea automáticamente un nuevo registro cuando completas la fila.
#
# ---
#
# ## 🎛 Herramientas de navegación
# En la parte inferior tienes el **record navigator**, donde puedes:
# - Mover entre registros
# - Saltar al primero o último
# - Crear uno nuevo
# - Ver la cantidad total de registros
#
# ---
#
# ## 🧠 Finalidad de esta lección
# - Entender cómo realizar tareas básicas de mantenimiento: **agregar, editar, eliminar**.
# - Comprender cómo Access maneja **el guardado automático**.
# - Evitar errores comunes, como borrar datos accidentalmente.
# - Familiarizarte con el uso cotidiano de las tablas antes de crear tus propias estructuras.

# %% [markdown]
# ## **Ordenar y Buscar Datos dentro de una Tabla en Access**
#
# En esta lección, el instructor explica cómo **usar una tabla no solo para editar datos**, sino también para **buscar y ordenar registros** dentro de la vista Datasheet. Estos comandos facilitan encontrar información rápidamente sin necesidad de crear una consulta formal.
#
# ### 🔑 ¿Qué quiere enseñar esta lección?
# - Cómo **ordenar** registros en una tabla.
# - Cómo usar la sección **Sort & Filter** del menú Home.
# - La diferencia entre **cambios de datos** (que Access guarda automáticamente) y **cambios de presentación** (como ordenamientos, que NO se guardan automáticamente).
# - Cómo regresar al orden original.
# - Cómo los métodos de ordenación son idénticos a los de Excel.
#
# ---
#
# ## 🗂 Ordenar registros (Sorting)
# Puedes ordenar cualquier columna de una tabla para facilitar la búsqueda visual.
# Solo necesitas:
#
# 1. Hacer clic en cualquier celda de la columna que quieres ordenar.
# 2. Ir al menú **Home → Sort & Filter**.
# 3. Elegir:
#    - **Ascending (A–Z)**
#    - **Descending (Z–A)**
#
# Ejemplo:
# Ordenar por **Country** de A a Z muestra primero Argentina, Austria, Belgium, etc.
#
# ---
#
# ## ➕ Métodos alternativos de ordenamiento
# También puedes ordenar desde el **menú del encabezado de la columna**:
#
# 1. Haz clic en la flecha ▼ del encabezado (ej. *Country*).
# 2. Elige *Sort Ascending* o *Sort Descending*.
#
# El resultado es el mismo que usando la cinta de opciones.
#
# ---
#
# ## 🔄 Regresar al orden original
# El orden “natural” del CustomerID se recupera al:
#
# 1. Seleccionar la columna **CustomerID**.
# 2. Aplicar un **Sort Ascending**.
#
# Esto regresa la tabla al orden en que originalmente estaba guardada.
#
# ---
#
# ## 💾 Guardado: datos vs. diseño  (muy importante)
# Access maneja dos tipos de cambios:
#
# ### 1. **Cambios en datos** (editar, agregar, eliminar)
# - Access **guarda automáticamente** al cambiar de fila.
# - No necesitas presionar ningún botón.
#
# ### 2. **Cambios en diseño de presentación** (ordenar, mover columnas, ajustar ancho)
# - Access **NO guarda automáticamente**.
# - Al cerrar la tabla, te preguntará si deseas guardar el diseño.
# - Si dices *No*, el orden y ajustes visuales no se conservan.
#
# Ejemplo de mensaje:
# > “Do you want to save changes to the design of table Customers?”
#
# ---
#
# ## 🧪 Actividad sugerida
# - Abrir la tabla **Customers**.
# - Ordenar por *Country*, *Contact Name* o *Company Name*.
# - Cambiar entre orden ascendente y descendente.
# - Cerrar la tabla y elegir *No* para ver cómo vuelve al estilo original.
# - Repetir para entender la diferencia entre **datos guardados automáticamente** y **diseño no guardado**.
#
# ---
#
# ### 🎯 Finalidad de esta lección
# - Mejorar tu eficiencia al explorar tablas grandes.
# - Saber cuándo tus cambios se guardan automáticamente y cuándo no.
# - Familiarizarte con funciones de ordenamiento que también existen en Excel.
# - Prepararte para trabajar con tablas de forma más profesional antes de pasar a temas más avanzados.

# %% [markdown]
# ## **Filtrar Datos en Tablas de Access (Filter by Selection)**
#
# En esta lección, el instructor enseña cómo **filtrar registros directamente desde una tabla** en Access usando la vista Datasheet. Esto ayuda a encontrar información de manera más rápida y precisa, sin necesidad de crear una consulta.
#
# ### 🔑 ¿Qué quiere enseñar esta lección?
# - Cómo aplicar **filtros rápidos** dentro de una tabla.
# - El uso del comando **Filter by Selection**.
# - Cómo filtrar por valores exactos, excluir valores, o filtrar por letra inicial.
# - Cómo quitar filtros y volver a la vista original.
# - Cómo combinar un ordenamiento previo con un filtro.
#
# ---
#
# ## 📌 1. ¿Qué es "Filter by Selection"?
# Es un método simple para filtrar datos directamente desde una celda.
# Permite mostrar únicamente los registros que **coinciden** con el valor (o parte del valor) que seleccionas.
#
# Funciona así:
# 1. Haz clic dentro del valor que quieras filtrar.
# 2. Ve a **Home → Sort & Filter → Selection**.
# 3. Elige la condición deseada (por ejemplo, *Equals Canada*).
#
# Access mostrará solo los registros que coincidan.
#
# ---
#
# ## 🇨🇦 Ejemplo: Filtrar países iguales a “Canada”
# 1. Haz clic dentro de una celda que diga “Canada”.
# 2. Ve a **Home → Selection → Equals Canada**.
# 3. Resultado: Solo aparecen los **3 registros** donde Country = Canada.
# 4. Un ícono de embudo (funnel) aparecerá en el encabezado indicando que la columna tiene un filtro activo.
#
# ---
#
# ## 🔄 Quitar el filtro
# - Usa **Home → Sort & Filter → Toggle Filter**.
# - Alterna entre vista filtrada y vista completa.
#
# ---
#
# ## 🛠 Tipos de filtros según selección
# Acceso ofrece varias opciones según lo que selecciones:
#
# ### 🔹 1. Filtrar por valor completo
# - *Equals [valor]*
# - *Does Not Equal [valor]*
#
# ### 🔹 2. Filtrar por contenido parcial
# Ideal para campos tipo texto más largos.
# - *Contains [texto]*
# - *Does Not Contain [texto]*
#
# ### 🔹 3. Filtrar por letra inicial (muy útil)
# Si **seleccionas solo una letra** (por ejemplo, “F” en “Finland”), Access habilita filtros especiales:
# - *Begins With F*
# - *Does Not Begin With F*
#
# Ejemplo:
# - Seleccionas la letra **F** → Filtras por países como *Finland* y *France*.
#
# ---
#
# ## 🧪 Actividad sugerida
# - Ordena la tabla por Country (opcional, para ver más claro).
# - Selecciona una celda con un valor, como “Mexico”.
# - Aplica **Filter by Selection**.
# - Selecciona una letra dentro del campo (solo la letra “G” en “Germany”).
# - Prueba *Begins With G*.
# - Usa **Toggle Filter** para volver al estado original.
#
# ---
#
# ## 🎯 Finalidad de esta lección
# - Entender cómo aplicar filtros rápidos sin crear consultas.
# - Facilitar la búsqueda de registros en tablas grandes.
# - Aprender opciones de filtrado similares a Excel, pero integradas en Access.
# - Preparar el camino hacia el uso de **criterios más avanzados** dentro de consultas.
#
# ``

# %% [markdown]
# ## **Filtros Avanzados en Tablas (Advanced Filter / Filter by Form)**
#
# En esta lección, el instructor explica el segundo método de filtrado dentro de Access: **Filter by Form**.
# Este método permite construir filtros más complejos, usando múltiples columnas, condiciones AND/OR y combinaciones más elaboradas que las que ofrece *Filter by Selection*.
#
# ### 🔑 ¿Qué quiere enseñar esta lección?
# - Cómo activar y usar el filtro avanzado.
# - Cómo ingresar criterios en múltiples campos.
# - Cómo funcionan los operadores **AND** y **OR** dentro del formulario de filtro.
# - Cómo ejecutar y limpiar los filtros.
# - Cuándo es mejor utilizar Filter by Form en lugar de Filter by Selection.
#
# ---
#
# ## 🧰 1. ¿Qué es *Filter by Form*?
# Es un modo de filtrado avanzado que:
# - Muestra una **vista vacía** de la tabla.
# - Proporciona un **formulario de criterios**, con menús desplegables por cada columna.
# - Te permite escribir condiciones para múltiples campos a la vez.
#
# Se accede desde:
# **Home → Sort & Filter → Advanced → Filter by Form**
#
# ---
#
# ## 🛠 2. Crear un filtro básico con *Filter by Form*
# Ejemplo: filtrar por **Country = Germany**
#
# 1. Abrir **Filter by Form**
# 2. En la columna **Country**, seleccionar **Germany**
# 3. Presionar **Toggle Filter**
# 4. La tabla mostrará solo los registros que cumplen el criterio (ej.: 11 resultados)
#
# ---
#
# ## 🧩 3. Combinar múltiples condiciones (AND)
# Si completas varios campos en la **misma línea**, Access interpreta:
#
# > **Country = Germany AND City = Berlin**
#
# Esto mostrará únicamente los registros que cumplan ambas condiciones al mismo tiempo.
#
# Ejemplo:
# - Antes: 11 registros con “Germany”
# - Después de agregar “Berlin”: solo 1 registro cumple ambas condiciones
#
# ---
#
# ## 🔀 4. Usar condiciones OR con la pestaña “Or”
# Filter by Form incluye una **segunda pestaña llamada “Or”**.
#
# Permite agregar criterios alternativos, por ejemplo:
#
# - Pestaña principal:
#   Country = Germany AND City = Berlin
# - Pestaña OR:
#   Country = Germany AND City = Frankfurt
#
# Resultado:
# Se muestran **ambas ciudades**, cada una cumpliendo su propio conjunto de criterios.
#
# Esto equivale a:
#
# > (Country = Germany AND City = Berlin)
# > **OR**
# > (Country = Germany AND City = Frankfurt)
#
# ---
#
# ## 🔄 5. Quitar el filtro
# - Usar **Toggle Filter** para aplicar o desactivar los filtros.
# - Usar **Advanced → Clear All Filters** para limpiar cualquier criterio definido.
#
# ---
#
# ## 🧪 Actividad sugerida
# - Abrir la tabla **Customers**.
# - Aplicar un Filter by Form:
#   - Country = Germany
#   - City = Berlin (AND)
# - Luego agregar un OR:
#   - Country = Germany AND City = Frankfurt
# - Ejecutar con **Toggle Filter**.
# - Observar cómo Access devuelve varios grupos de criterios combinados.
#
# ---
#
# ## 🎯 Finalidad de esta lección
# - Aprender una forma más poderosa de filtrar datos directamente en la tabla.
# - Crear filtros complejos sin necesidad de usar consultas.
# - Entender las diferencias entre:
#   - **Filter by Selection:** rápido y simple
#   - **Filter by Form:** avanzado y flexible
# - Preparar el camino hacia criterios avanzados dentro de las consultas.
