# %% [markdown]
# ## **Relaciones entre tablas en Access**
#
# En una base de datos de Access, cada tabla contiene información independiente (por ejemplo: **Students**, **Courses** y **StudentSchedule**). Para que estas tablas puedan relacionarse, se deben crear **relaciones** basadas en campos comunes.
#
# ### Conceptos clave
#
# - **Clave primaria (Primary Key)**
#   Campo único que identifica cada registro dentro de una tabla.
#   Ejemplos:
#   - `StudentID` en la tabla **Students**
#   - `CourseID` en la tabla **Courses**
#
# - **Clave foránea (Foreign Key)**
#   Es la clave primaria de otra tabla colocada como un campo dentro de una tabla secundaria.
#   Permite crear la relación entre ambas.
#   Ejemplo: agregar `StudentID` dentro de **StudentSchedule** para saber qué cursos tiene un estudiante.
#
# ### Cómo funciona una relación
#
# 1. La tabla principal (por ejemplo, **Students**) tiene un campo único llamado clave primaria.
# 2. Ese mismo campo se agrega en otra tabla (por ejemplo, **StudentSchedule**) como clave foránea.
# 3. En la tabla secundaria **no debe ser clave primaria**, porque un estudiante puede tener múltiples cursos y el valor debe repetirse.
# 4. Esta coincidencia de campos permite que Access vincule ambas tablas.
# 5. Gracias a la relación, desde la tabla de estudiantes se puede abrir la sub‑hoja de datos y ver los cursos inscritos.
#
# ### Objetivo
#
# Vincular las tablas de forma lógica para consultar información relacionada, como saber qué cursos tiene cada estudiante. El siguiente paso consiste en crear las relaciones dentro del panel de diseño de Access.
# ``

# %% [markdown]
# ## **crear relaciones entre tablas en Access**
#
# Dentro de la base de datos de cursos y estudiantes, existen tres tablas: **Students**, **Courses** y **StudentSchedule**. Cada una contiene información independiente y todavía no se relacionan entre sí. El objetivo es vincularlas para saber qué cursos tiene asignado cada estudiante.
#
# ### Primer intento: relacionar Students → Courses
#
# 1. Para crear una relación directa entre estudiantes y cursos, se intentó agregar el campo **StudentID** dentro de la tabla **Courses**.
# 2. Al agregar el campo, se tuvo que ajustar su **tipo de dato** para que coincidiera con el de la tabla principal:
#    - En `Students`, *StudentID* es **AutoNumber**.
#    - En `Courses`, el campo agregado debe ser **Number**, nunca AutoNumber.
# 3. Tras esto, se ingresaron valores manualmente, asignando estudiantes a cursos dentro de la tabla Courses.
#
# ### Problema de este enfoque
#
# Este diseño genera **redundancia**:
# - Si un curso (ejemplo: PowerPoint) es tomado por varios estudiantes, habría que **duplicar el registro del curso muchas veces**, uno por cada estudiante.
# - Esto provoca:
#   - Repetición innecesaria de datos.
#   - Riesgo de errores al escribir nombres o instructores.
#   - Que Access cree múltiples registros diferentes del mismo curso por culpa del AutoNumber.
#   - Falta de integridad y mala normalización de la base de datos.
#
# ### Resultado del intento
#
# - La relación sí se puede crear (arrastras `StudentID` desde Students hacia `StudentID` en Courses).
# - Access muestra las subhojas y permite ver los cursos de cada estudiante.
# - **Pero** el diseño es ineficiente y no escalable.
#
# ### Conclusión
#
# Aunque esta relación funciona técnicamente, **no es la mejor práctica**. Duplicar cursos cada vez que un estudiante se inscribe es incorrecto y genera un sistema difícil de mantener.
# En la siguiente mejora, se usa la tabla **StudentSchedule** como tabla intermedia para evitar redundancia y lograr un diseño profesional.

# %% [markdown]
# ## **Mejor enfoque para crear relaciones entre tablas usando una tabla intermedia (junction table)**
#
# Después del intento inicial de relacionar directamente **Students → Courses** agregando `StudentID` dentro de la tabla **Courses**, se encontró un problema serio: **redundancia de datos**. Para solucionarlo, se usa un mejor diseño basado en una **tabla intermedia** llamada **StudentSchedule**.
#
# ---
#
# ### 1. Limpieza del intento anterior
# - Se eliminó el registro duplicado de "Intro to PowerPoint".
# - Se eliminó el campo `StudentID` de la tabla **Courses**.
# - Se eliminó la relación creada previamente para modificar la estructura.
# - Se guardaron los cambios y se dejó limpia la tabla de cursos.
#
# ---
#
# ### 2. El problema original: relación muchos-a-muchos (N:M)
# - Un estudiante puede tomar muchos cursos.
# - Un curso puede tener muchos estudiantes.
# - Esto crea una **relación muchos-a-muchos**.
# - Si se intenta resolver insertando `StudentID` o `CourseID` directamente en la otra tabla:
#   - Se duplica información.
#   - Las tablas crecen sin necesidad.
#   - Hay más probabilidad de errores.
#   - El diseño pierde eficiencia.
#
# Ejemplo: El curso PowerPoint se repetiría tantas veces como estudiantes inscritos haya.
#
# ---
#
# ### 3. Solución correcta: tabla intermedia **StudentSchedule**
# Para evitar la redundancia se introduce una tabla “puente” o **junction table**.
#
# La tabla **StudentSchedule** incluye:
# - `StudentID`
# - `CourseID`
# - (Opcional) datos adicionales, como `Grade`.
#
# Cada uno de estos campos puede repetirse **por separado**, pero:
# - **La combinación de ambos no debe repetirse.**
#
# Así se transforma la relación N:M en dos relaciones 1:N:
#
# - **Students 1 → N StudentSchedule**
# - **Courses 1 → N StudentSchedule**
#
# ---
#
# ### 4. Creación de las nuevas relaciones
# Desde *Database Tools → Relationships*:
#
# 1. Insertar las tres tablas: **Students**, **Courses**, **StudentSchedule**.
# 2. Arrastrar `StudentID` desde **Students** hacia `StudentID` de **StudentSchedule**.
# 3. Arrastrar `CourseID` desde **Courses** hacia `CourseID` de **StudentSchedule**.
# 4. Completar la relación (luego se pueden ajustar opciones como integridad referencial).
#
# El resultado es un diseño profesional, eficiente y sin redundancia.
#
# ---
#
# ### 5. Resultado final en la base de datos
# - **Students**:
#   - Al hacer clic en "+" se ven los cursos en los que está inscrito el estudiante.
# - **Courses**:
#   - Al hacer clic en "+" se ven los estudiantes inscritos en ese curso.
# - **StudentSchedule**:
#   - Contiene las combinaciones StudentID–CourseID necesarias sin duplicar cursos ni estudiantes.
#
# #### Beneficios
# - Las tablas principales permanecen limpias (un registro por estudiante, un registro por curso).
# - La redundancia desaparece.
# - El sistema es escalable.
# - La estructura respeta las reglas de normalización.
#
# ---
#
# ### 6. Conclusión
# La tabla intermedia **StudentSchedule** es la forma correcta de manejar relaciones muchos-a-muchos en Access.
# Permite inscribir múltiples estudiantes en múltiples cursos sin duplicar datos ni inflar las tablas principales.
#
# Se recomienda:
# - Revisar las relaciones desde la ventana de Relationships.
# - Verificar que al abrir los símbolos “+” en Students y Courses aparezcan los datos vinculados.
# - Practicar la creación de estas relaciones hasta dominar el concepto.

# %% [markdown]
# ## **Propiedades de las relaciones en Access y uso de la integridad referencial**
#
# Ya contamos con las relaciones principales entre las tablas **Students**, **Courses** y **StudentSchedule**, pero hasta ahora habíamos ignorado la ventana emergente de *Relationship Properties*. Esta ventana es clave porque define cómo se comportan las relaciones dentro de la base de datos.
#
# A continuación se explica cómo funcionan estas propiedades y por qué son importantes.
#
# ---
#
# ### 1. Reconstrucción de las relaciones para ver la ventana de propiedades
# Para analizar las opciones, se eliminaron temporalmente las relaciones:
# - Clic derecho sobre cada línea → **Delete**.
# - Luego se arrastró nuevamente:
#   - `StudentID` (Students) → `StudentID` (StudentSchedule)
#   - `CourseID` (Courses) → `CourseID` (StudentSchedule)
#
# Esto vuelve a mostrar la ventana donde se configuran las propiedades de la relación.
#
# ---
#
# ### 2. Entendiendo la ventana de Relationship Properties
#
# Cuando arrastras un campo desde la tabla principal hacia la tabla relacionada, Access muestra una ventana que especifica:
#
# - **Las tablas que se están relacionando**
# - **Los campos involucrados**
# - **El tipo de relación** (1 a muchos, 1:1, etc.)
#
# En este caso:
# - `StudentID` en **Students** es 1.
# - `StudentID` en **StudentSchedule** es Muchos.
# - Aunque `StudentID` también es clave primaria en StudentSchedule, no es única por sí sola:
#   La combinación `StudentID + CourseID` es lo que garantiza unicidad.
#
# Resultado: **Relación 1 → Muchos**.
#
# ---
#
# ### 3. El problema sin integridad referencial
# Si simplemente presionas **Create**, la relación funciona… pero es vulnerable.
#
# Sin **Enforce Referential Integrity**, pueden suceder errores graves:
#
# - Ejemplo:
#   - Cambias un `StudentID` en la tabla **Students** (p. ej., de 4 a 20).
#   - Los registros de StudentSchedule siguen teniendo el valor antiguo (4).
#   - Ahora existen registros "huérfanos":
#     StudentSchedule contiene un estudiante que “no existe” en Students.
#
# Esto rompe la consistencia de la base de datos.
#
# ---
#
# ### 4. Qué hace “Enforce Referential Integrity”
# Activar **Enforce Referential Integrity** evita registros huérfanos y asegura coherencia entre tablas.
#
# Cuando está activado:
# - No puedes cambiar el `StudentID` en la tabla principal si existen registros relacionados.
# - No puedes borrar un estudiante si está en StudentSchedule (a menos que uses *cascade delete*).
# - La base se mantiene consistente automáticamente.
#
# Esto es **indispensable** en bases de datos serias.
#
# ---
#
# ### 5. ¿Por qué Access no activa esta opción por defecto?
# Access no lo hace automáticamente por una razón importante:
#
# **Muchos usuarios importan datos externos**, como Excel o archivos de otro sistema.
#
# Esos datos:
# - pueden contener errores,
# - duplicados,
# - IDs sin correspondencia,
# - o registros mal formados.
#
# Si Access aplicara la integridad referencial de inmediato:
# - la relación fallaría,
# - los datos no podrían conectarse,
# - el usuario no podría avanzar.
#
# Por eso Access permite primero importar y **luego** limpiar y validar los datos antes de activar la integridad.
#
# ---
#
# ### 6. Cómo activar correctamente la integridad referencial
# 1. Crear la relación arrastrando los campos.
# 2. En la ventana emergente:
#    - Activar **Enforce Referential Integrity**.
# 3. Confirmar y crear la relación.
# 4. La línea de relación ahora mostrará un “1” conectado a un símbolo de infinito (∞) indicando la relación 1:N válida y reforzada.
#
# ---
#
# ### 7. Verificación final
# Después de activar la integridad, puedes:
#
# - Abrir **Students** y desplegar el símbolo “+” para ver los cursos del estudiante.
# - Abrir **Courses** y desplegar el “+” para ver los estudiantes inscritos.
#
# Todo estará sincronizado y consistente.
#
# ---
#
# ### 8. Conclusión
# Activar la integridad referencial garantiza que:
# - No existan registros huérfanos.
# - Los cambios en las claves primarias no rompan las relaciones.
# - La base de datos sea estable, confiable y profesional.
#
# Es un paso crucial después de crear las relaciones correctamente usando la tabla intermedia **StudentSchedule**.

# %% [markdown]
# ## **Configuración avanzada de relaciones en Access: Cascade Update y Cascade Delete**
#
# Una vez que se ha activado **Enforce Referential Integrity** en una relación de Access, aparecen dos opciones adicionales muy importantes: **Cascade Update** y **Cascade Delete**. Estas permiten controlar cómo se comportan los registros relacionados cuando cambian o se eliminan datos en la tabla principal.
#
# ---
#
# ## 1. Accediendo a las opciones
# 1. Abrir *Database Tools → Relationships*.
# 2. Hacer clic derecho en la línea de relación.
# 3. Seleccionar **Edit Relationship**.
# 4. Ahí aparecen:
#    - Enforce Referential Integrity (ya activado previamente)
#    - Cascade Update Related Fields
#    - Cascade Delete Related Records
#
# ---
#
# ## 2. Cascade Update Related Fields (Actualización en cascada)
#
# ### ¿Qué hace?
# Permite que si cambias un **ID** en la tabla principal (por ejemplo en Students), Access actualice automáticamente ese mismo ID en todas las tablas relacionadas (como StudentSchedule).
#
# ### Ejemplo:
# - StudentID pasa de `1` a `001`.
# - Si **Cascade Update** está activado:
#   - Access actualiza automáticamente todos los registros en StudentSchedule que usaban el ID 1.
# - Sin Cascade Update:
#   - StudentSchedule conservará el viejo ID, creando registros “huérfanos” y rompiendo la integridad del sistema.
#
# ### Ventaja:
# Evita trabajo manual enorme.
# Sin esta función tendrías que actualizar cada tabla relacionada **a mano**.
#
# ---
#
# ## 3. Cascade Delete Related Records (Eliminación en cascada)
#
# ### ⚠️ Advertencia importante
# Esta opción es extremadamente poderosa y peligrosa.
# Si la activas, **borrar un registro en la tabla principal elimina automáticamente TODOS los registros relacionados** en las tablas secundarias.
#
# ### Ejemplo:
# - Eliminando al estudiante con ID 4:
#   - Si **Cascade Delete** está activado:
#     - Access borra todas las filas de StudentSchedule donde StudentID = 4.
#   - Si NO está activado:
#     - Access **no te dejará borrar ese estudiante** mientras existan registros relacionados.
#
# ### Riesgo:
# - No hay papelera.
# - No hay deshacer.
# - Una vez borrado: **se perdió para siempre**.
#
# ### Buenas prácticas:
# - Activar Cascade Delete **solo mientras se realiza una limpieza específica**.
# - Apagarlo inmediatamente después.
# - Evitar dejarlo activado de forma permanente.
#
# ---
#
# ## 4. Por qué estas opciones no vienen activadas por defecto
# Access no activa referential integrity, cascade update ni cascade delete automáticamente porque:
#
# - Muchos usuarios importan datos desde Excel u otros sistemas.
# - Esos datos pueden tener:
#   - IDs repetidos
#   - Registros sin correspondencia
#   - Errores de estructura
# - Si Access intentara hacer validaciones estrictas desde el inicio, las relaciones **fallarían** durante la importación.
#
# Por eso Access permite:
# 1. Importar los datos.
# 2. Revisarlos y limpiarlos.
# 3. Luego activar las reglas avanzadas de integridad.
#
# ---
#
# ## 5. Resultado final con integridad y cascadas
# Una vez activadas las opciones adecuadas:
#
# - La relación Students → StudentSchedule queda correctamente protegida.
# - Los IDs se mantienen sincronizados.
# - Los registros no se quedan “huérfanos”.
# - La base de datos funciona de forma estable, confiable y segura.
#
# Generalmente se recomienda:
# - **Usar Cascade Update cuando sea necesario.**
# - **Usar Cascade Delete solo con extrema precaución.**
#
# ---
#
# ## 6. Aplicación práctica
# Al final del proceso:
# - Se vuelve a crear la relación CourseID → CourseID.
# - Se activa:
#   - Enforce Referential Integrity
#   - Cascade Update (opcional y seguro)
# - La relación queda sólida.
# - Puedes navegar los sub-datasheets con el símbolo “+” sin inconsistencias.
#
# Estas configuraciones son parte esencial del diseño profesional de bases de datos en Access.
#
# ``

# %% [markdown]
# ## **Uso práctico de las relaciones: inserción de datos a través de subhojas (subdatasheets)**
#
# Una vez creadas las relaciones entre las tablas del sistema (Students, Courses y StudentSchedule) y activada la **integridad referencial**, es posible trabajar con los datos de forma más fluida: desde una tabla se puede añadir información relacionada sin necesidad de abrir múltiples ventanas.
#
# ---
#
# ## 1. Insertar información desde la tabla Courses usando las subhojas
# - Al abrir **Courses**, aparece un símbolo “+” junto a cada curso.
# - Ese “+” despliega la información proveniente de la tabla **StudentSchedule**, la cual a su vez está relacionada con **Students**.
# - Esto permite inscribir estudiantes directamente desde la tabla Courses.
#
# ### Ejemplo:
# 1. Abrir *Courses*.
# 2. Elegir un curso (por ejemplo, *Intro to Access*).
# 3. Presionar el “+” para abrir la subhoja.
# 4. Agregar un nuevo registro indicando:
#    - `StudentID` (ej. 5)
#    - Fecha de inicio (1 de diciembre)
#    - Fecha de fin (30 de enero)
#    - Horario (1 p.m. a 2 p.m.)
#    - Día de la semana (lunes)
#
# Con esto, el estudiante queda inscrito al curso sin necesidad de escribir en múltiples tablas directamente.
#
# ---
#
# ## 2. Visualizar los cambios desde la tabla Students
# - Al abrir **Students** y expandir el estudiante 5 (Brant Byrnes), se puede ver el registro recién creado.
# - La información aparece automáticamente porque está guardada en **StudentSchedule**, que es la tabla que gestiona las inscripciones.
#
# Esto confirma que las relaciones están funcionando correctamente.
#
# ---
#
# ## 3. Verificación en la tabla StudentSchedule
# - Al abrir la tabla **StudentSchedule**, puede verse el nuevo registro agregando:
#   - `CourseID`
#   - `StudentID`
#   - Fechas y horarios asociados
#
# Esta tabla es la que conecta lógicamente a Students y Courses sin duplicar datos.
#
# ---
#
# ## 4. Ventaja principal: trabajar desde cualquier tabla sin duplicar esfuerzos
# Gracias a las relaciones:
# - Puedes abrir **Courses** y asignar estudiantes desde ahí.
# - O abrir **Students** y asignarlos a cursos desde esa vista.
# - Sin abrir ventanas adicionales.
# - Sin moverte manualmente entre tablas.
# - Y con integridad garantizada.
#
# Esto convierte el trabajo en algo mucho más **rápido, limpio y organizado**.
#
# ---
#
# ## 5. Conclusión
# Ahora que:
# - Las relaciones están creadas,
# - La integridad referencial está activa, y
# - Las subhojas funcionan,
#
# puedes gestionar múltiples tablas desde un solo punto sin riesgo de inconsistencia y sin duplicar datos. Este comportamiento representa una de las mayores ventajas del diseño relacional en Access.
#
# ``

# %% [markdown]
# ## **Mejorando la entrada de datos con listas desplegables (Lookup Wizard)**
#
# Aunque las relaciones entre tablas y la integridad referencial reducen la redundancia y mejoran la consistencia, seguir viendo solo **IDs numéricos** en las subhojas puede ser confuso.
# Especialmente cuando necesitas inscribir estudiantes en cursos y no recuerdas qué ID corresponde a cada nombre.
#
# Para evitar tener que abrir múltiples tablas y buscar IDs manualmente, Access permite transformar un campo numérico en un **campo con lista desplegable (lookup)** que muestra nombres legibles mientras mantiene los IDs internamente.
#
# ---
#
# ## 1. El problema: ver solo IDs en las subhojas
# Ejemplo:
# - Abres la tabla **Courses**.
# - Expandes la subhoja (gracias a la relación con StudentSchedule).
# - Ves filas con `StudentID` como: 6, 5, 8…
# - Necesitas agregar a “Joe”… pero, ¿qué ID es Joe?
#
# Esto obliga a:
# 1. Abrir la tabla Students.
# 2. Buscar a Joe (ID 4).
# 3. Regresar a Courses e ingresar manualmente el ID → **poco eficiente**.
#
# ---
#
# ## 2. Solución: usar Lookup Wizard para mostrar nombres en vez de IDs
# La idea es convertir el campo **StudentID** dentro de la tabla **StudentSchedule** en un campo con desplegable que muestre:
# **Nombre + Apellido**, mientras internamente sigue guardando el ID.
#
# Para lograrlo es necesario **eliminar temporalmente la relación** con StudentSchedule.
#
# ---
#
# ## 3. Pasos para crear la lista desplegable en StudentSchedule
#
# ### 🔹 Paso 1: Eliminar la relación temporalmente
# - Abrir *Database Tools → Relationships*.
# - Clic derecho en la relación **Students → StudentSchedule**.
# - Seleccionar **Delete**.
#
# *(La relación con Courses puedes eliminarla después si quieres aplicar el mismo proceso allí.)*
#
# ---
#
# ### 🔹 Paso 2: Abrir la tabla StudentSchedule en diseño
# 1. Abrir *StudentSchedule*.
# 2. Ir a **Design View**.
# 3. Seleccionar el campo **StudentID**.
#
# ---
#
# ### 🔹 Paso 3: convertirlo en un campo tipo Lookup
# 1. Temporariamente cambiar el **Data Type** a **Lookup Wizard**.
# 2. Elegir la opción:
#    - **I want the lookup field to get values from another table or query.**
# 3. Seleccionar la tabla **Students (TBL Students)**.
# 4. Elegir los campos a mostrar:
#    - `FirstName`
#    - `LastName`
# 5. Ordenar por apellido (opcional).
# 6. Mantener la opción **Hide key column** activada:
#    - Access seguirá usando el ID internamente.
# 7. Confirmar el nombre del campo (StudentID).
# 8. Activar integridad referencial (sin permitir eliminación).
# 9. Finalizar.
#
# Access pedirá guardar la tabla porque está creando una nueva relación → seleccionar **Yes**.
#
# ---
#
# ## 4. Resultado del lookup
# Al volver a la vista hoja de datos:
#
# - El campo **StudentID** ya muestra un **menú desplegable con nombres completos**.
# - Internamente Access sigue guardando los valores numéricos del ID.
# - Ya no necesitas abrir la tabla Students para buscar números.
#
# Ejemplo visual:
#
# En lugar de:
#
# | StudentID |
# |-----------|
# | 6 |
# | 5 |
# | 8 |
#
# Ahora verás:
#
# | StudentID (Lookup)      |
# |-------------------------|
# | Brent Burns             |
# | Logan Couture           |
# | Joe Pavelski            |
#
# ---
#
# ## 5. Uso práctico desde otras tablas
# Al abrir la tabla **Courses** y expandir un curso:
#
# - La subhoja mostrará ahora un desplegable con nombres en lugar de IDs.
# - Puedes inscribir estudiantes fácilmente:
#   - Seleccionas el nombre desde la lista.
#   - Agregas fechas, horarios, etc.
#
# Sin memorizar números.
# Sin saltar entre tablas.
# Todo en una sola pantalla.
#
# ---
#
# ## 6. Conclusión
# Implementar lookups con el **Lookup Wizard**:
#
# - Hace la entrada de datos más rápida.
# - Evita errores humanos.
# - Facilita el trabajo para cualquier usuario del sistema.
# - Aprovecha mejor las relaciones ya establecidas.
# - Mantiene los IDs correctamente a nivel interno.
#
# Este paso convierte un modelo relacional funcional en un sistema realmente **usable y eficiente**.
