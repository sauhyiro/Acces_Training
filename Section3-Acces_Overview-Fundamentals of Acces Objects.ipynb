# %% [markdown]
# ## **Tablas en Access y su Importancia**
#
# El instructor presenta las **tablas** como el objeto más importante y la base de cualquier base de datos en Microsoft Access. Son el **fundamento donde se almacena toda la información**.
#
# ### 🔑 ¿Qué son las tablas?
# - Son estructuras que contienen datos organizados en **filas (registros)** y **columnas (campos)**.
# - Funcionan de forma similar a una hoja de Excel, pero con un propósito más estructurado.
# - En la base Northwind, las tablas incluyen: *Customers, Orders, Employees, Products*, etc.
#
# ### 🧱 Función principal
# - **Almacenar datos estructurados**.
# - Cada tabla contiene información de un solo tipo (clientes, pedidos, productos…).
# - Juntas forman la base de datos completa.
#
# ### 🔄 Relaciones entre tablas
# - Las tablas no están aisladas: se **relacionan entre sí**.
# - Ejemplo:
#   - Un **customer** puede tener muchos **orders**.
#   - Un **order** pertenece a un **employee**.
#   - Un **order** contiene varios **products**.
#
# ### ➕ Subdatasheets (subtablas)
# - Access permite expandir registros usando el ícono **+**.
# - Esto muestra datos relacionados sin abrir otras tablas.
# - Ejemplo de niveles:
#   1. Customers
#   2. Orders del cliente
#   3. Products dentro de ese order
#
# ### 🆚 Comparación con Excel
# - En Excel podrías tener:
#   - Varias hojas (clientes, productos, pedidos…)
#   - O una sola hoja gigantesca con todo mezclado.
# - En Access:
#   - Los datos se **dividen en tablas más pequeñas**.
#   - **Las relaciones** permiten conectarlas de forma eficiente.

# %% [markdown]
# ## **Relaciones entre Tablas en Access**
#
# Antes de avanzar a las consultas, el instructor explica la importancia de las **relaciones** entre tablas, ya que permiten conectar datos en Access y son esenciales para que funciones como las subdatasheets y las consultas trabajen correctamente.
#
# ### 🔑 ¿Qué quiere enseñar esta lección?
# - Cómo funcionan las **relaciones** entre tablas.
# - Cómo se vinculan campos clave (ej. `CustomerID`).
# - Cómo Access puede mostrar información relacionada usando los **subdatasheets** (+).
# - Dónde se configuran y administran las relaciones.
#
# ### 🧱 ¿Qué son las relaciones?
# - Son conexiones entre tablas basadas en un **campo común** (llave primaria y llave externa).
# - Permiten vincular información lógica:
#   - Clientes → Órdenes
#   - Órdenes → Detalles de orden
#   - Órdenes → Empleados
#   - Detalles de orden → Productos
#
# ### 🟦 Subdatasheets (los botones “+”)
# - Muestran datos relacionados sin abrir otras tablas.
# - Ejemplo:
#   1. Cliente → sus órdenes
#   2. Orden → sus productos (order details)
# - Solo funcionan **si existe una relación** correctamente definida.
#
# ### 🛠 ¿Dónde se administran las relaciones?
# - Pestaña **Database Tools → Relationships**.
# - Allí se visualizan:
#   - Tablas
#   - Campos
#   - Líneas que representan cada relación
#
# ### 🔁 Crear o eliminar relaciones
# - **Eliminar**: clic derecho sobre la línea → Delete
#   - Al hacerlo, desaparecen los "plus" del subdatasheet.
# - **Crear**: arrastrar un campo clave desde una tabla a su campo relacionado en otra.
#   - Ejemplo: `CustomerID` (Customers) → `CustomerID` (Orders)
#
# ### 🎯 Finalidad de esta lección
# - Entender que Access funciona gracias a:
#   - Tablas separadas con **información específica**
#   - Relaciones que **unen** esos datos
# - Preparar al alumno para consultas, formularios y otras funcionalidades que dependen de estas conexiones.

# %% [markdown]
# ## **Consultas (Queries) en Microsoft Access**
#
# En esta sección, el instructor introduce el siguiente objeto fundamental de Access: **las consultas (queries)**. Son esenciales para buscar, combinar y filtrar datos que provienen de una o varias tablas relacionadas.
#
# ### 🔑 ¿Qué quiere enseñar esta lección?
# - Qué es una consulta y por qué es necesaria.
# - Cómo una consulta permite reunir datos de varias tablas.
# - Los tres modos principales para visualizar una consulta:
#   - **Datasheet View**
#   - **SQL View**
#   - **Design View**
# - Cómo aplicar **criterios** para filtrar resultados.
# - Cómo todo lo que muestra una consulta proviene siempre de las **tablas**.
#
# ### 📌 ¿Qué es una consulta?
# - Es una herramienta para **buscar y presentar** datos almacenados en tablas.
# - Puede combinar información de varias tablas relacionadas (ej. Customers, Orders, Products).
# - El resultado se presenta como una tabla, pero **no es una tabla**: es una vista de datos extraídos.
#
# ### 📊 Datasheet View
# - Vista que parece una tabla.
# - Permite ver el conjunto de resultados.
# - Si modificas o borras registros aquí, **estás cambiando los datos en las tablas originales**.
#
# ### 🧩 SQL View
# - Muestra el lenguaje SQL que genera la consulta.
# - Contiene:
#   - `SELECT` de los campos
#   - Tablas involucradas
#   - Relaciones implícitas
# - Access genera este SQL automáticamente cuando diseñas la consulta visualmente.
#
# ### 🛠 Design View (vista más importante)
# - Donde realmente se construyen las consultas.
# - Partes clave:
#   - **Lista de tablas** involucradas
#   - **Grid de diseño** para seleccionar campos
#   - Área de **criterios** para aplicar filtros
# - Permite arrastrar campos desde las tablas al grid sin necesidad de escribir SQL.
#
# ### 🎯 Ejemplo práctico
# - Abrir la consulta *Invoices* (ya existente en Northwind).
# - Agregar un criterio en **ShipCountry** para mostrar solo resultados de *USA*.
# - Cambiar entre vistas para comprobar el resultado.
# - Ver cómo el filtrado reduce los 2155 registros iniciales a solo aquellos que cumplen el criterio.
#
# ### 🔍 ¿Para qué sirven las consultas?
# - Combinar datos dispersos en varias tablas.
# - Realizar búsquedas y filtros (por país, precio, fecha, cliente, etc.).
# - Preparar datos para informes, formularios o análisis.
# - Evitar duplicar información en distintas tablas.
#
# ### 🧪 Actividad sugerida
# - Abrir la consulta *Invoices*.
# - Ir a **Design View**.
# - Agregar un criterio (USA, Canada, Mexico, etc.) en **ShipCountry**.
# - Volver a **Datasheet View** y validar el filtro.
# - Así se aprende la lógica de consultas antes de crear las propias.

# %% [markdown]
# ## **Formularios (Forms) en Microsoft Access**
#
# Los formularios son el tercer objeto fundamental de Access. Mientras las **tablas** almacenan datos y las **consultas** permiten buscar y filtrar esos datos, los **formularios** sirven como la **interfaz principal para interactuar con la información** de manera más intuitiva y eficiente.
#
# ### 🔑 ¿Qué quiere enseñar esta lección?
# - Qué es un formulario y por qué se utiliza.
# - Cómo los formularios facilitan la edición y captura de datos.
# - Por qué son más eficientes que trabajar directamente con tablas o consultas.
# - Los dos tipos de formularios:
#   - Formularios de **interacción con datos**
#   - Formularios de **presentación o navegación**
# - Cómo los cambios hechos en un formulario afectan a las tablas.
#
# ---
#
# ### 🧱 ¿Qué es un formulario?
# - Es una **interfaz visual** para trabajar con datos.
# - Puede basarse en:
#   - Una tabla
#   - Una consulta (que a su vez viene de las tablas)
# - Permite **agregar, editar y eliminar** registros de forma más clara y controlada.
#
# ---
#
# ### 🖥 ¿Por qué usar un formulario si puedo editar la tabla o la consulta?
# - Un formulario muestra **solo un registro a la vez**, lo que:
#   - Reduce errores
#   - Facilita el enfoque en la información relevante
# - Evita que el usuario tenga que navegar entre múltiples tablas (customers, orders, products…).
# - Proporciona un entorno **más limpio, guiado y profesional**.
# - Permite incluir:
#   - Botones
#   - Controles
#   - Cálculos
#   - Validaciones
#   - Navegación personalizada
# - Ideal para **usuarios finales** que no deben interactuar directamente con tablas.
#
# ---
#
# ### 🧪 Ejemplo: Formulario *Orders*
# El instructor abre el formulario **Orders**, el cual muestra:
# - Datos del cliente
# - Información de envío y facturación
# - Empleado asignado
# - Productos del pedido
# - Totales y cálculos
# - Botón de impresión integrado
#
# Todo esto sin tener que navegar manualmente por múltiples tablas o consultas.
#
# ---
#
# ### 📋 Tipos de formularios
# 1. **Formularios de entrada y edición de datos**
#    Diseñados para trabajar con registros.
#    Ejemplo: *Orders*, *Products*, *Customers*.
#
# 2. **Formularios de presentación o navegación (dashboard / switchboard)**
#    Diseñados para mostrar pantallas iniciales o menús.
#    Ejemplos:

# %% [markdown]
# ## **Reportes (Reports) en Microsoft Access**
#
# Los reportes son el cuarto objeto fundamental de Access. Después de almacenar datos (tablas), consultarlos (queries) e interactuar con ellos (formularios), los reportes sirven para **presentar y comunicar la información**, normalmente en formatos profesionales, imprimibles o exportables.
#
# ### 🔑 ¿Qué quiere enseñar esta lección?
# - Qué es un reporte y para qué se usa.
# - Diferencia entre reportes basados en una sola tabla y reportes basados en consultas.
# - Ejemplos reales de reportes útiles: facturas, catálogos, listados, resúmenes.
# - Cómo un reporte presenta información de forma clara, agrupada y lista para imprimir.
# - Por qué *pensar primero en los reportes* ayuda a diseñar mejor una base de datos.
#
# ---
#
# ### 🧾 ¿Qué es un reporte?
# Un **reporte** es una presentación final del contenido de la base de datos.
# Se usa para **visualizar, imprimir o exportar** información de forma ordenada y profesional.
#
# Ejemplos típicos:
# - Facturas (Invoices)
# - Catálogos de productos
# - Listas de clientes
# - Productos descontinuados
# - Reportes diarios o mensuales de pedidos
#
# Un reporte puede basarse en:
# 1. **Una tabla** (si la información está toda en un mismo lugar)
# 2. **Una consulta** (cuando necesitas combinar múltiples tablas)
#
# ---
#
# ### 🧩 Ejemplo: Reporte de Invoices
# - El instructor abre el reporte **Invoices**.
# - Presenta:
#   - Datos del cliente
#   - Datos de envío y facturación
#   - Productos del pedido
#   - Totales y cálculos
# - Puede tener **muchas páginas** (el ejemplo muestra más de 800).
#
# Es una forma profesional de imprimir o generar archivos PDF con la información del negocio.
#
# ---

# %% [markdown]
# ## **Macros y Módulos en Microsoft Access (Automatización)**
#
# Los últimos dos objetos fundamentales de Access son **Macros** y **Módulos**. Ambos sirven para **automatizar tareas** dentro de la base de datos, pero funcionan a niveles distintos y con diferentes niveles de complejidad.
#
# ### 🔑 ¿Qué quiere enseñar esta lección?
# - Qué son las macros y los módulos.
# - Cuándo se usa cada uno.
# - Cómo estos objetos sirven para automatizar procesos dentro de Access.
# - Que son temas avanzados que se verán más adelante en el curso.
# - Un cierre general de todos los objetos de Access y su propósito.
#
# ---
#
# ## 🟦 Macros: Automatización sin programar
# - Son herramientas para **automatizar tareas comunes** sin escribir código.
# - Se utilizan para:
#   - Imprimir reportes automáticamente.
#   - Validar datos en formularios.
#   - Ejecutar acciones al hacer clic en un botón.
#   - Abrir formularios, aplicar filtros, importar datos, etc.
# - Funcionan mediante una interfaz con **menús desplegables**, sin escribir código.
# - Son ideales para usuarios que no programan.
#
# > Las macros siguen el mismo concepto que en Excel: ejecutar una serie de acciones de forma automática.
#
# ---
#
# ## 🟥 Módulos: Automatización con VBA (Visual Basic for Applications)
# - Son objetos que **contienen código VBA**, escrito a mano.
# - Se usan cuando se necesita:
#   - Lógica compleja.
#   - Personalización avanzada.
#   - Validaciones específicas.
#   - Automatización que excede lo que permite una macro.
# - Requieren abrir el **VBA Editor** (Ventana de código).
# - El curso cubrirá desde lo básico hasta procedimientos más avanzados.
#
# > Los módulos permiten construir funciones, procedimientos y automatizaciones totalmente personalizadas.
#
# ---
#
# ## 🤖 ¿Qué automatizan Macros y Módulos?
# Ambos pueden automatizar tareas como:
# - Generar reportes con un solo clic.
# - Validar información en un formulario.
# - Actualizar múltiples tablas.
# - Ejecutar acciones en secuencia.
# - Mejorar la experiencia del usuario.
#
# La diferencia principal:
#
# | Objeto | Nivel | Qué automatiza | Requiere código |
# |-------|-------|----------------|-----------------|
# | **Macros** | Fácil | Tareas comunes | No |
# | **Módulos (VBA)** | Avanzado | Lógica compleja | Sí |
#
# ---
#
# ## 🧱 Cierre: Resumen de todos los objetos de Access
# El instructor resume los 6 objetos principales:
#
# 1. **Tables (Tablas)**
#    - La base de todo.
#    - Donde se **almacenan** los datos.
#
# 2. **Queries (Consultas)**
#    - Extraen datos desde una o más tablas.
#    - Permiten **filtrar, calcular, combinar** información.
#
# 3. **Forms (Formularios)**
#    - Interfaz para **ver, capturar o editar** datos.
#    - Más fácil y seguro que editar directamente las tablas.
#
# 4. **Reports (Reportes)**
