# %% [markdown]
# ## **Crear una Base de Datos Nueva desde Cero en Access**
#
# En esta lección, el instructor muestra cómo iniciar una **base de datos completamente nueva**, sin plantillas, para comenzar a construir tablas y todos los demás objetos de Access desde cero.
#
# ### 🔑 ¿Qué quiere enseñar esta lección?
# - Cómo crear un archivo de base de datos vacío.
# - Diferencias entre plantillas y bases en blanco.
# - Cómo nombrar y guardar el archivo.
# - La extensión moderna de bases de datos en Access (`.accdb`).
# - Qué sucede al crear una nueva base de datos (Access crea una primera tabla por defecto).
# - Preparar el entorno para comenzar a construir la base de datos del curso: *Student Courses*.
#
# ---
#
# ## 📂 1. Crear una nueva base de datos en blanco
# Desde la pantalla inicial de Access:
#
# 1. Ir a **File → New**
# 2. Ignorar las plantillas (pueden ayudar, pero no las usaremos ahora)
# 3. Seleccionar **Blank Database**
# 4. Ingresar un nombre para el archivo
#    Ejemplo del curso:
#    **student_courses_01**
# 5. Elegir ubicación donde guardar (por defecto: *Documents*)
# 6. Hacer clic en **Create**
#
# Esto genera el archivo de base de datos vacío.
#
# ---
#
# ## 📁 2. Extensión moderna de Access (`.accdb`)
# - Desde Access 2007 en adelante, la extensión oficial es **`.accdb`**.
# - Bases antiguas (como Northwind) usan **`.mdb`**.
# - Al crear una base nueva, siempre obtendrás un archivo `.accdb`.
#
# ---
#
# ## 🧱 3. ¿Qué contiene la base recién creada?
# Al crear una base de datos en blanco, Access automáticamente:
#
# - Crea un archivo vacío con el nombre elegido.
# - Genera **una primera tabla predeterminada** (llamada *Table1*).
# - Abre esa tabla para que puedas empezar a definir campos.

# %% [markdown]
# ## **Crear la Estructura Inicial de la Primera Tabla en Access (Design View)**
#
# En esta lección se explica cómo construir la **estructura base de la primera tabla** dentro de la nueva base de datos *Student Courses*. El enfoque principal es definir correctamente los **campos (columnas)** y sus **tipos de datos**, siguiendo buenas prácticas de diseño de bases de datos.
#
# ### 🔑 Objetivos de la lección
# - Cambiar de Datasheet View a Design View para editar la estructura.
# - Nombrar correctamente la tabla utilizando prefijos (TBL).
# - Añadir campos con sus respectivos tipos de datos.
# - Evitar errores comunes como:
#   - Usar nombres con espacios
#   - Guardar información combinada en un solo campo
#   - Elegir tipos de datos incorrectos (ej. usar Number para teléfonos)
# - Entender la importancia de la normalización (separar valores en unidades significativas).
#
# ---
#
# ### 🗂 1. Cambiar a Design View y nombrar la tabla
# Cuando creas una base de datos nueva, Access genera una tabla por defecto.
# Para estructurarla correctamente:
#
# 1. Ir a **Home → View → Design View**
# 2. Dar nombre a la tabla, usando prefijos recomendados:
#    - **TBL_Students**
#
# Los prefijos ayudan a identificar el tipo de objeto más adelante en consultas, macros o código VBA.
#
# ---
#
# ### 🧩 2. Definir campos fundamentales
# El campo inicial “ID” se renombra a:
#
# - **StudentID** → Short Text
#   *(evitar espacios en nombres de campo)*
#
# Luego se añaden los campos principales:
#
# - **FirstName** – Short Text
# - **LastName** – Short Text
# - **Address** – Short Text
# - **City** – Short Text
# - **State** – Short Text
# - **PhoneNumber** – Short Text
#
# Access permite elegir el tipo de dato desde un menú desplegable para cada campo.
#
# ---
#
# ### 🧠 3. Normalización: separar valores en partes útiles
# El instructor recalca un principio básico de diseño:
#
# > Un campo debe almacenar el valor más pequeño y significativo posible.
#
# Por eso **NO** se recomienda:
# - ❌ *StudentName* (une nombre y apellido)
#
# Sino:
# - ✔️ *FirstName*
# - ✔️ *LastName*
#
# Esto permite:
# - Ordenar por apellido
# - Filtrar por nombre
# - Usarlos por separado en reportes o formularios
#
# ---
#
# ### 🔡 4. Elegir el tipo de dato correcto
# Aunque algunos campos parezcan numéricos, no deben ser del tipo *Number*.
#
# Ejemplo: **PhoneNumber**
# - No debe ser Number porque:
#   - Puede tener guiones (-)
#   - Paréntesis ( )
#   - Espacios
#   - Código internacional (+)
# - Por lo tanto, debe ser: **Short Text**
#
# ---
#
# ### ⚙️ 5. Field Properties
# En la parte inferior de Design View se pueden configurar propiedades adicionales.
# Para Short Text, la más importante es:
#
# - **Field Size**: máximo 255 caracteres (configurable)
#
# No es obligatorio modificarla en esta etapa.
#
# ---
#
# ### 👀 6. Verificación en Datasheet View
# Después de crear los campos:
#
# 1. Guardar los cambios
# 2. Volver a **Datasheet View**
# 3. Ver la tabla ya formada, con todas las columnas definidas
#
# Aún no se ingresan datos; eso viene después.
#
# ---
#
# ### 🎯 Finalidad de la lección
# - Construir la estructura inicial de la tabla *TBL_Students*.
# - Aplicar buenas prácticas de diseño desde el inicio.
# - Comprender por qué la selección del tipo de dato importa.
# - Preparar la base para futuras tablas, relaciones, formularios y consultas.

# %% [markdown]
# ## **Comprendiendo los Tipos de Datos en Access y Cuándo Usarlos**
#
# En esta lección, el instructor profundiza en los **tipos de datos** disponibles en Access y por qué es fundamental elegir correctamente el tipo adecuado para cada campo. Esto afecta cómo los usuarios ingresan datos, qué valores se permiten y cómo funcionarán consultas, formularios y validaciones más adelante.
#
# ### 🔑 Objetivos de la lección
# - Conocer todos los tipos de datos disponibles en Access.
# - Aprender a usar la ayuda integrada (F1) para ver descripciones completas.
# - Entender por qué elegir el tipo correcto evita errores y facilita el trabajo posterior.
# - Aplicar tipos de datos adecuados según el significado del valor (no solo “lo que parece”).
#
# ---
#
# ### 🧰 Tipos de datos en Access (Introducción)
# En Design View, cada campo tiene una columna “Data Type”.
# Al abrir el menú desplegable, Access muestra opciones como:
#
# - **Short Text**
# - **Long Text**
# - **Number**
# - **Date/Time**
# - **Currency**
# - **AutoNumber**
# - **Yes/No**
# - **OLE Object**
# - **Hyperlink**
# - **Attachment**
# - **Lookup Wizard**, etc.
#
# La lista puede variar según la versión, pero los conceptos son los mismos.
#
# El instructor recomienda usar **F1** para abrir la ayuda oficial de Microsoft:
# - Describe cada tipo
# - Da ejemplos de uso
# - Aclara diferencias entre versiones (ej. Memo → Long Text)
#
# ---
#
# ### 📌 Ejemplos importantes explicados en la lección
#
# #### **Short Text**
# - Reemplaza al antiguo tipo *Text*.
# - Hasta 255 caracteres.
# - Ideal para: nombres, direcciones, teléfonos, estados, códigos, textos cortos.
#
# #### **Long Text** (antes Memo)
# - Para textos largos: notas, comentarios, descripciones extensas.
#
# #### **Number**
# - Solo para valores matemáticos.
# - **No usar para teléfonos, códigos postales, IDs, etc.**
#
# #### **AutoNumber**
# - Genera un número automático para cada nuevo registro.
# - Perfecto para claves primarias como un “ID”.
#
# #### **Yes/No**
# - Muestra un checkbox.
# - Útil para estados binarios (activo/inactivo, sí/no, aprobado/no aprobado).
#
# #### **Date/Time**
# - Para fechas reales que deban filtrarse, ordenarse o calcularse.
#
# ---
#
# ### 🧠 Aplicación práctica: Elegir el tipo adecuado
#
# El instructor añade un nuevo campo:
# **Active**
#
# Pregunta: ¿Qué tipo de dato debe usarse?
#
# Opciones posibles:
# - Short Text → se podría escribir “Yes/No”, pero no es ideal.
# - Lookup Wizard → para crear listas desplegables personalizadas.
# - **Yes/No → opción recomendada.**
#
# Resultado:
# - Campo se muestra como un *checkbox* ✔
# - Intuitivo para el usuario
# - Más fácil de manipular en consultas y formularios
#
# ---
#
# ### 📚 Ejemplo de uso de F1 (muy recomendado)
# Cuando seleccionas un tipo de dato y presionas **F1**, Access abre la página oficial de Microsoft con:
# - Descripción completa
# - Límites
# - Compatibilidad entre versiones
# - Propiedades relacionadas (como Field Size)
#
# Es una herramienta esencial cuando estás aprendiendo o validando decisiones de diseño.
#
# ---
#
# ### 🧩 Reflexión importante en esta lección
# El instructor invita a pensar:
# **¿Qué otros datos deberíamos almacenar de un estudiante y qué tipo de dato conviene para cada uno?**
#
# Ejemplos típicos:
# - Fecha de nacimiento → Date/Time
# - Email → Short Text
# - Estatus de beca → Yes/No
# - GPA → Number (con decimales)
# - Fecha de inscripción → Date/Time
# - Género → Lookup Wizard (lista desplegable)
#
# ---
#
# ### 🎯 Finalidad de la lección
# - Comprender profundamente los tipos de datos disponibles.
# - Tomar decisiones correctas desde el inicio del diseño.
# - Evitar errores comunes (como usar Number donde no corresponde).
# - Preparar el terreno para completar la tabla y avanzar hacia relaciones y formularios.

# %% [markdown]
# ## **Ajustar Field Properties en Tablas de Access (Controlar Longitud y Calidad de Datos)**
#
# En esta lección, el instructor amplía la construcción de la tabla **TBL_Students**, añadiendo nuevos campos y mostrando cómo las **Field Properties** permiten controlar la calidad del dato ingresado. La idea principal es evitar “datos sucios” y asegurar que la información siga reglas claras desde el principio.
#
# ### 🔑 Objetivos de la lección
# - Añadir campos adicionales al diseño de la tabla.
# - Comprender qué son las *Field Properties* y por qué son importantes.
# - Ajustar el tamaño máximo de texto permitido (*Field Size*).
# - Asegurar consistencia y evitar errores comunes de ingreso de datos.
# - Entender cómo validar entradas con límites razonables (ej. estados, ciudades, nombres).
#
# ---
#
# ### 🧩 1. Campos nuevos agregados en la tabla
# El instructor añade cuatro campos adicionales:
#
# - **DateEnrolled** → Date/Time
# - **DateGraduation** → Date/Time
# - **Advisor** → Short Text
# - **Major** → Short Text
#
# Estos campos permiten capturar información adicional del estudiante, y sirven como base para la validación posterior.
#
# ---
#
# ### ⚙️ 2. ¿Qué son las Field Properties?
# En Design View, al seleccionar un campo, en la parte inferior aparece una sección llamada:
#
# > **Field Properties**
#
# Aquí se controla **cómo se comporta ese campo**, incluyendo:
#
# - Tamaño máximo permitido (Field Size)
# - Reglas de formato
# - Reglas de validación
# - Texto por defecto
# - Más opciones dependiendo del tipo de dato
#
# En esta lección se enfoca en **Field Size**, la propiedad clave para campos Short Text.
#
# ---
#
# ### ✂️ 3. Reducir el Field Size para evitar datos sucios
# Access asigna automáticamente **255 caracteres** a cualquier campo Short Text.
#
# Pero esto es *excesivo* y genera varios problemas:
#
# - Los usuarios pueden escribir cosas incorrectas.
# - La base se llena de valores inconsistentes.
# - No se puede ordenar ni filtrar correctamente.
# - Las consultas y reportes se dañan por datos mal ingresados.
#
# Por eso, el instructor recomienda **limitar el tamaño según lo razonable**.
#
# Ejemplos:
#
# | Campo | Field Size recomendado | Justificación |
# |-------|-------------------------|---------------|
# | FirstName | 50 | Ningún nombre real supera eso. |
# | LastName | 50 | Igual que FirstName. |
# | City | 50 | Suficiente para ciudades largas. |
# | State | 2 (si usas abreviaciones) | Evita variaciones incorrectas. |
# | Address | 100–150 | Direcciones pueden ser largas. |
#
# ---
#
# ### 🚨 4. Por qué esto es crítico: la historia del “dirty data”
# El instructor cuenta un caso real:
#
# Una empresa creó encuestas sin validación.
# Resultado:
#
# - Algunas personas escribían “Utah”
# - Otras “UT”
# - Otras “ut”
# - Otras “Utha” (con errores)
# - Otras “Utah State”
# - etc.
#
# Cuando intentaron hacer reportes y cálculos:
# - Los datos no coincidían.
# - No podían agrupar por estado.
# - Tuvieron que limpiar todo manualmente (muchas horas de trabajo perdido).
#
# ⭐ **Lección clave:**
# Agregar validación desde el diseño de tablas ahorra enormes problemas en el futuro.
#
# ---
#
# ### 🧪 5. Actividad recomendada por el instructor
# Antes de continuar:
#
# 1. Revisa cada campo Short Text.
# 2. Piensa:
#    **“¿Cuál es el tamaño máximo razonable que quiero permitir?”**
# 3. Ajusta *Field Size* para cada caso.
# 4. Guarda y verifica en Datasheet View.
#
# Esto establece un estándar de calidad para tu base de datos.
#
# ---
#
# ### 🎯 Finalidad de la lección
# - Mejorar la integridad del diseño de la tabla.
# - Evitar inconsistencias y errores de datos.
# - Crear reglas claras para ingreso de información.
# - Preparar el terreno para propiedades aún más avanzadas en las siguientes lecciones.

# %% [markdown]
# ## **Usar la Propiedad *Caption* para Mostrar Nombres Claros sin Romper Buenas Prácticas**
#
# En esta lección el instructor explica cómo resolver un problema común en diseño de bases de datos:
# **necesitamos nombres de campo sin espacios para trabajar correctamente en Access, SQL o VBA**,
# pero al mismo tiempo **queremos que los encabezados se vean profesionales** en tablas, formularios y reportes.
#
# La solución: **la propiedad Caption**.
#
# ---
#
# ### 🔑 Objetivos de la lección
# - Comprender por qué NO se deben usar espacios en los nombres de campo.
# - Evitar problemas futuros en SQL, VBA y wizards.
# - Usar la propiedad **Caption** para mostrar nombres amigables al usuario.
# - Mantener buenas prácticas internas mientras la interfaz se ve clara y profesional.
#
# ---
#
# ## 🚫 1. Por qué NO usar espacios en nombres de campo
# Aunque Access permite escribir nombres como **"Student ID"**, es una mala práctica porque:
#
# - En SQL, los nombres con espacios requieren corchetes:
#   `SELECT [Student ID] FROM TBL_Students`
# - En VBA se vuelven incómodos y propensos a errores.
# - En macros y wizards generan código más complejo.
#
# Por eso se recomienda usar nombres internos como:
#
# - `StudentID`
# - `FirstName`
# - `LastName`
# - `EnrollmentDate`
#
# ---
#
# ## 🟢 2. El problema: así se ve “feo” en pantalla
# Aunque internamente usamos nombres sin espacios, visualmente se ve poco profesional:
#
# - `StudentID`
# - `FirstName`
# - `LastName`
#
# Si esto aparece en tablas, formularios o reportes, no es ideal para usuarios finales.
#
# ---
#
# ## 🟡 3. La solución: Propiedad **Caption**
# En Design View:
#
# 1. Selecciona el campo
# 2. En la sección **Field Properties**, busca:
#    **Caption**
# 3. Escribe el texto amigable que quieres mostrar.
#
# Ejemplos:
#
# | Nombre interno (sin espacios) | Caption visible |
# |-------------------------------|-----------------|
# | StudentID                     | Student ID      |
# | FirstName                     | First Name      |
# | LastName                      | Last Name       |
# | DateEnrolled                  | Date Enrolled   |
# | LName                         | Last Name       |
#
# **Importante:**
# La *Caption* **solo afecta la interfaz**, NO cambia el nombre real del campo.
#
# ---
#
# ## 👀 4. Resultado
# Después de configurar las captions:
#
# - La tabla en Datasheet View se ve profesional.
# - Los reportes mostrarán etiquetas limpias.
# - Los formularios tendrán textos amigables.
# - El código SQL/VBA sigue siendo limpio y fácil de manipular.
#
# Ejemplo:
#
# Antes (nombre interno):
# `FirstName`
#
# Después (caption):
# **First Name**
#
# ---
#
# ## 🧪 Actividad recomendada
# Aplicar Caption a todos los campos existentes:
#
# - StudentID → "Student ID"
# - FirstName → "First Name"
# - LastName → "Last Name"
# - Address → "Address"
# - City → "City"
# - State → "State"
# - PhoneNumber → "Phone Number"
# - DateEnrolled → "Date Enrolled"
# - GraduationDate → "Graduation Date"
# - Advisor → "Advisor"
# - Major → "Major"
#
# Ajusta según tus abreviaciones o normas internas.
#
# ---
#
# ## 🎯 Finalidad de la lección
# - Mantener buenas prácticas de diseño (sin espacios en nombres internos).
# - Mejorar la presentación sin afectar la estructura técnica.
# - Preparar la tabla para su uso posterior en formularios, consultas y reportes.

# %% [markdown]
# ## **Propiedad *Default Value* en Access (Automatización de Valores Iniciales)**
#
# En esta lección se explica cómo usar la propiedad **Default Value** para que ciertos campos se llenen automáticamente cuando se crea un nuevo registro en la tabla. Esta propiedad reduce la repetición, evita errores y mejora la calidad de los datos.
#
# ### 🔑 Ideas principales de la lección
# - *Default Value* establece un valor automático cuando se agrega un nuevo registro.
# - Puede usarse para campos con valores repetitivos (ej. estado, ciudad, asesor).
# - También puede usar **funciones** (como `Date()`) para valores dinámicos.
# - Todo se configura desde **Design View**, en la sección de *Field Properties*.
#
# ### 🟦 Ejemplo 1: Valor por defecto para el estado (State)
# Si la mayoría de estudiantes provienen del mismo estado (ej. Utah), se puede configurar:
#
# 1. Seleccionar el campo `State` en Design View.
# 2. Ir a **Default Value**.
# 3. Escribir: `"UT"`
# 4. Guardar y revisar en Datasheet View.
#
# Cada nuevo registro tendrá **UT** automáticamente sin escribirlo manualmente.
#
# ### 🟩 Ejemplo 2: Fecha actual como valor por defecto (DateEnrolled)
# Para que la fecha de inscripción sea siempre la fecha del día:
#
# 1. Seleccionar el campo `DateEnrolled`.
# 2. En **Default Value**, dar clic al botón de los **tres puntos (Expression Builder)**.
# 3. Buscar funciones → Built-in Functions → Date/Time.
# 4. Insertar la función: Date()
#
# 5. Guardar y revisar.
#
# Ahora cada nuevo registro tendrá **la fecha actual** sin intervención del usuario.
#
# ### 🟧 Dónde puede usarse Default Value
# Se puede aplicar a prácticamente cualquier campo:
#
# - `Advisor` → `"Dr. Smith"`
# - `Active` → `True`
# - `City` → `"Salt Lake City"`
# - `Major` → `"General Studies"`
#
# Sirve tanto para valores constantes como para funciones dinámicas.
#
# ### 🟣 Beneficios de usar Default Value
# - Acelera la captura de datos repetitivos.
# - Minimiza errores humanos.
# - Evita inconsistencias (ej. “UT”, “Utah”, “ut”, “Utha”).
# - Incrementa la calidad del dataset.
# - Ayuda a automatizar procesos básicos desde la tabla.
#
# ### 🧪 Actividad sugerida
# - Establece `"UT"` como default en `State`.
# - Establece `Date()` como default en `DateEnrolled`.
# - Prueba otro default (ej. `Advisor`, `City` o `Active`).
# - Crea nuevos registros en Datasheet View para verificar que funciona.
#
# ### 🎯 Conclusión
# La propiedad *Default Value* es una herramienta simple pero poderosa que automatiza datos repetitivos y garantiza consistencia. Es una parte fundamental del diseño correcto de tablas antes de pasar a propiedades más avanzadas.

# %% [markdown]
# ## **Propiedad *Required* en Access (Campos Obligatorios)**
#
# En esta lección se explica cómo usar la propiedad **Required** para obligar al usuario a capturar información esencial antes de permitir que un registro sea guardado. Esto evita datos incompletos y garantiza la calidad mínima de cada fila en la tabla.
#
# ### 🔑 Idea central
# La propiedad *Required* define si un campo puede quedar vacío (**No**) o si debe tener un valor obligatoriamente (**Yes**) antes de guardar un registro.
#
# ---
#
# ### 📝 Cómo funciona la propiedad *Required*
# En **Design View**:
#
# 1. Selecciona un campo (por ejemplo: `FirstName`).
# 2. En la sección **Field Properties**, busca la propiedad:
#    **Required**
# 3. Cámbiala de **No** a **Yes**.
# 4. Guarda la tabla.
#
# Si el usuario intenta guardar un registro sin llenar ese campo, Access bloqueará la acción y mostrará un mensaje.
#
# ---
#
# ### 🟦 Ejemplo aplicado en la lección
# El instructor marca como obligatorios:
#
# - `FirstName`
# - `LastName`
#
# Motivo: estos campos representan información fundamental del estudiante, así que la base de datos **no debe permitir registros sin nombre completo**.
#
# ---
#
# ### 📌 Comportamiento durante la captura de datos
# Cuando *Required = Yes*:
#
# - El usuario **no puede guardar el registro** si deja el campo vacío.
# - Tampoco puede moverse a otro registro sin completar el valor.
# - En formularios (que veremos más adelante), Access mostrará mensajes claros que indican el error.
#
# Esto mejora la calidad de la base y evita registros incompletos como:
# - Estudiantes sin nombre
# - Registros sin fechas obligatorias
# - Campos clave sin información relevante
#
# ---
#
# ### 🧪 Actividad recomendada
# - Ve a Design View en tu tabla `TBL_Students`.
# - Marca como Required los campos que siempre deben tener un valor:
#   - `FirstName`
#   - `LastName`
#   - `DateEnrolled` (si lo decides)
#   - `State` (si siempre debe existir)
# - Guarda la tabla.
# - Ve a Datasheet View e intenta guardar un registro sin llenar esos campos para ver cómo Access lo evita.
#
# ---
#
# ### 🎯 Conclusión
# La propiedad **Required** es una forma simple pero poderosa de garantizar *datos completos y válidos*. Ayuda a prevenir errores desde el origen y mantiene la base de datos más limpia y fiable, especialmente cuando más adelante se usen formularios, consultas y reportes basados en esos valores.

# %% [markdown]
# ## **Propiedad *Input Mask* en Access (Controlar y Estandarizar la Forma de Captura)**
#
# En esta lección se presenta una propiedad fundamental para garantizar que los usuarios ingresen la información con un formato consistente: **Input Mask**. Su propósito es evitar errores de captura, estandarizar datos y asegurar que valores como teléfonos, fechas o códigos postales tengan siempre la misma estructura.
#
# ### 🔑 Idea central
# Sin una *Input Mask*, los usuarios pueden ingresar valores con cualquier formato, lo que genera inconsistencias (ej. números telefónicos escritos con guiones, paréntesis, puntos, o sin formato). La propiedad *Input Mask* permite definir **cómo debe escribirse el dato**, obligando a seguir una estructura específica.
#
# ---
#
# ### 🟦 Cómo aplicar una Input Mask a un campo
# 1. Ir a **Design View**.
# 2. Seleccionar el campo (ej. `PhoneNumber`).
# 3. En **Field Properties**, localizar **Input Mask**.
# 4. Hacer clic en los tres puntos (…)
# 5. Se abre el **Input Mask Wizard**, con máscaras predefinidas.
# 6. Elegir una de la lista (por ejemplo: *Phone Number*).
# 7. Probar el formato en la caja “Try it”.
# 8. Personalizar si es necesario y finalizar.
#
# ---
#
# ### ☎️ Ejemplo aplicado: Phone Number
# El asistente selecciona la máscara de teléfono predefinida.
# Incluye:
# - Paréntesis para el área `(###)`
# - Espacio
# - Tres dígitos
# - Guion `-`
# - Últimos cuatro dígitos
#
# También explica los símbolos usados en la máscara:
# - **0** = dígito obligatorio
# - **9** = dígito opcional
# - **Literal characters** (paréntesis, guion, espacios) se muestran automáticamente
# - **Placeholder** = carácter que aparece antes de escribir (por defecto `_`, pero puede cambiarse a `#` por mejor visibilidad)
#
# Ejemplo de máscara final: (000) 000-0000
#
# El usuario solo escribe números: Access formatea automáticamente.
#
# ---
#
# ### 🧩 Requerir todos los dígitos
# Si se desea que el código de área sea obligatorio, se reemplazan los `9` por `0`.
#
# Ejemplo: (000) 000-0000
#
# (obliga a ingresar todos los 10 dígitos)
#
# ---
#
# ### 🧼 Guardar datos con o sin símbolos
# Al final del asistente Access pregunta:
#
# **¿Deseas almacenar los datos con o sin los caracteres del formato?**
#
# - **Con símbolos** → se guarda `(801) 555‑1212`
# - **Sin símbolos** → se guarda `8015551212`
#
# La elección depende de:
# - Sistemas externos que recibirán los datos
# - Reglas de validación de otras plataformas
# - Preferencias del diseño de base
#
# ---
#
# ### 🧪 Ejemplo adicional: Postal Code / ZIP Code
# Se agrega un campo nuevo (`PostalCode`) y se puede aplicar una máscara similar:
#
# - 5 dígitos estrictos (EE.UU.)  00000
#
# - Códigos mixtos alfanuméricos (Canadá) L0L-0L0
#
# (L = letra obligatoria, 0 = número obligatorio)
#
# ---
#
# ### 🎯 Beneficios del Input Mask
# - Consistencia absoluta en valores clave.
# - Evita errores típicos de formato (guiones extra, espacios erróneos, mezcla de estilos).
# - Ahorra tiempo al usuario al tener la estructura pre‑formada.
# - Garantiza que las consultas, reportes y exportaciones funcionen correctamente.
# - Ya no dependes de que cada usuario “lo escriba a su manera”.
#
# ---
#
# ### 🧪 Actividad recomendada
# - Crear una máscara de teléfono usando el wizard.
# - Crear una máscara personalizada para ZIP o Postal Code.
# - Probar una máscara para fechas.
# - Verificar en Datasheet View cómo aparece la estructura cuando comienzas a teclear.
#
# ---
#
# ### ✔️ Conclusión
# **Input Mask es una herramienta esencial para controlar la forma en que los usuarios ingresan datos.**
# Permite estandarizar la captura desde el nivel más básico: la tabla. Esto evita datos sucios, errores de formato y problemas futuros en reportes, formularios y exportaciones.

# %% [markdown]
# ## Tabla de caracteres y formatos para crear Input Masks en Access
#
# | Carácter / Símbolo | Significado en Input Mask | Tipo de dato permitido | Ejemplo de uso | Ejemplo de máscara completa |
# |--------------------|---------------------------|-------------------------|----------------|------------------------------|
# | `0` | Dígito obligatorio (0–9) | Numérico | Teléfono básico | `000-0000` |
# | `9` | Dígito opcional (0–9) | Numérico | Extensión opcional | `000-0009` |
# | `#` | Dígito o espacio, opcional, puede ser + o - | Numérico con signos | Código con signo | `##0` |
# | `L` | Letra obligatoria (A–Z) | Texto alfabético | Código estatal | `LL` |
# | `?` | Letra opcional (A–Z) | Texto alfabético | Código mixto | `L??` |
# | `A` | Letra o dígito obligatorio | Alfanumérico | Códigos mixtos | `AA00` |
# | `a` | Letra o dígito opcional | Alfanumérico | Variante flexible | `aa00` |
# | `&` | Carácter obligatorio (cualquier tipo) | Cualquier carácter | Claves | `&&&&` |
# | `C` | Carácter opcional | Cualquier carácter | Comentarios cortos | `CCCC` |
# | `>` | Convierte todo a mayúsculas | Modificador | Abreviaturas | `>LL` |
# | `<` | Convierte todo a minúsculas | Modificador | Códigos sensibles | `<llll` |
# | `!` | Rellena desde la izquierda (por defecto derecha) | Modificador | Formatos invertidos | `!00000` |
# | `\` | Carácter “escapado” (literal) | Texto literal | Mostrar símbolos específicos | `\(999\)` |
# | `"`texto"` | Incluye texto literal dentro de la máscara | Texto fijo | Prefijos obligatorios | `"ID"-0000` |
# | `;` | Separador de secciones | N/A | Control del almacenamiento | `>LL;0;_` |
#
# ---
#
# ## Ejemplos adicionales de Input Masks completas
#
# | Propósito | Mask | Descripción |
# |----------|------|-------------|
# | Teléfono (USA) | `(000) 000-0000` | Requiere área + número |
# | Teléfono (USA) opcional área | `(999) 000-0000` | El área puede omitirse |
# | Código postal (USA) | `00000` | ZIP de 5 dígitos |
# | ZIP+4 | `00000\-0000` | Código postal extendido |
# | Estado (2 letras mayúsculas) | `>LL` | Abreviatura obligatoria |
# | RFC mexicano simplificado | `>LLLL000000???` | Letras obligatorias + números + alfanumérico |
# | Matrícula escolar | `AA\-0000` | 2 letras + guion + 4 dígitos |
# | Placas de auto (MX) | `LLL\-0000` | 3 letras + guion + números |
# | Código alfanumérico variable | `AAAAA` | 5 caracteres obligatorios |
# | Fecha (usa formato input mask, no tipo Date) | `00/00/0000` | Forza captura dd/mm/aaaa |
# | Hora | `00:00` | Hora 24h |
# | Serial con prefijo | `"SER"-000000` | Texto fijo + números |

# %% [markdown]
# ## **Crear un Campo con Lista Desplegable (Lookup Wizard) para Controlar la Captura de Datos**
#
# En esta lección se presenta una propiedad clave que combina **tipo de dato + asistente (wizard)** para crear listas desplegables dentro de una tabla. El objetivo es asegurar **consistencia total** en los valores ingresados por el usuario, evitando errores de escritura, variaciones ortográficas y datos incorrectos.
#
# ### 🔑 Idea principal
# En lugar de dejar que los usuarios escriban libremente valores como *majors* o *carreras*, se configura un campo que solo permita elegir opciones predefinidas mediante un **dropdown**. Esto garantiza que los datos estén estandarizados desde la tabla.
#
# ---
#
# ### 🟦 ¿Qué es el Lookup Wizard?
# Es un asistente dentro de Access que transforma un campo normal en un **campo tipo lista**.
# Esto permite que, al capturar datos, el usuario seleccione un valor en lugar de escribirlo.
#
# Se accede desde **Design View**, cambiando el `Data Type` de un campo a: Lookup Wizard
#
# ---
#
# ### 🧭 Proceso para crear la lista desplegable (ejemplo con Major)
# 1. En **Design View**, seleccionar el campo `Major`.
# 2. Cambiar su **Data Type** a **Lookup Wizard**.
# 3. El asistente pregunta de dónde vendrán los valores:
#    - Opción 1: desde otra tabla/consulta.
#    - **Opción 2 (usada aquí): escribir los valores manualmente.**
# 4. Ingresar los valores que aparecerán en la lista. Ejemplo:
#    - Media Arts
#    - IT
#    - Web Development
#    - HR
#    - Accounting
# 5. Elegir si:
#    - El usuario está **limitado a la lista** (recomendado).
#    - Se permite seleccionar **múltiples valores** (opcional).
# 6. Finalizar y guardar la tabla.
#
# ---
#
# ### 🧪 Resultado en Datasheet View
# Al revisar la tabla:
#
# - El campo `Major` muestra un **desplegable** en cada celda.
# - El usuario solo puede elegir entre las opciones permitidas.
# - Se evita que un usuario escriba variaciones como:
#   - "Web Dev"
#   - "web development"
#   - "WeB DeVeLoPmEnT"
#   - "IT."
#   - "I.T."
#   - "Human Resources"
#   - "HRR"
#
# Esto garantiza uniformidad absoluta.
#
# ---
#
# ### 🎯 Beneficios del Lookup Wizard
# - **Estandariza** valores desde la fuente.
# - Evita errores de ortografía o formatos inconsistentes.
# - Simplifica filtros, reportes y consultas posteriores.
# - Facilita la captura de datos para usuarios no técnicos.
# - Permite listas simples o avanzadas según el caso.
#
# ---
#
# ### 🧩 Cuándo usarlo
# Es ideal para campos que deben tener valores consistentes, por ejemplo:
#
# - Major / Carrera
# - Departamento
# - Categoría
# - Estado / Estatus
# - Tipo de usuario
# - Modalidad de curso
# - Turno (mañana/tarde/noche)
#
# ---
#
# ### ✔️ Conclusión
# El **Lookup Wizard** transforma un campo en una lista desplegable fácil de usar y totalmente controlada.
# Es una herramienta esencial para mejorar la precisión de la base de datos y garantizar que los valores críticos siempre se capturen correctamente.

# %% [markdown]
# ## **Editar y Administrar un Campo Lookup desde la Pestaña *Lookup* (Row Source)**
#
# En esta lección se explica que un campo creado con **Lookup Wizard** no solo depende del *Data Type*, sino también de una segunda parte fundamental: la configuración detallada ubicada en la pestaña **Lookup** dentro de las propiedades del campo. Esta pestaña controla por completo cómo funciona la lista desplegable.
#
# ### 🔑 Idea principal
# Todo Lookup creado con el asistente tiene **dos partes**:
# 1. **Data Type = Lookup Wizard** → crea el campo tipo lista.
# 2. **Lookup Tab (propiedades)** → controla y permite editar la lista, el origen de datos y el comportamiento del dropdown.
#
# ---
#
# ## 🟦 1. Dónde encontrar la pestaña Lookup
# En **Design View**:
#
# 1. Selecciona el campo que usa un Lookup (ej. `Major`).
# 2. En la parte inferior, además de la pestaña **General**, aparece la pestaña **Lookup**.
# 3. Esta pestaña muestra todas las configuraciones creadas por el wizard.
#
# ---
#
# ## 🧩 2. Editar la lista (Row Source)
# El parámetro más importante en un Lookup es:
#
# ### **Row Source**
# Contiene los valores que se mostrarán en la lista desplegable.
#
# Ejemplo real de la lección: "Media Arts";"IT";"Web Development";"HR";"Accounting"
#
# Puedes editar directamente:
# - Corregir errores ortográficos
# - Añadir opciones nuevas
# - Quitar opciones
# - Cambiar el orden visual
#
# Ejemplo de edición agregando **Music**: "Media Arts";"IT";"Web Development";"HR";"Accounting";"Music"
#
# Después de guardar, la opción aparece automáticamente en el dropdown.
#
# ---
#
# ## 🛠 3. Estructura del Row Source
# - Cada valor debe ir entre **comillas**.
# - Los valores deben separarse con **punto y coma (;)**.
# - El orden en el Row Source = orden en la lista desplegable.
#
# ---
#
# ## 🧪 4. Ver actualización en Datasheet View
# Al abrir la tabla:
#
# - El campo `Major` mostrará un **dropdown interno**.
# - La lista desplegable reflejará cualquier cambio hecho en Row Source.
# - Los usuarios solo verán las opciones permitidas (si *Limit to List = Yes*).
#
# ---
#
# ## 📝 5. Otros parámetros útiles dentro del Lookup Tab
# Aunque la lección no profundiza en ellos, los parámetros clave que aparecen aquí incluyen:
#
# - **Display Control**
#   - Determina si el campo es Combo Box, List Box o Text Box.
#
# - **Row Source Type**
#   - Value List (lista escrita a mano)
#   - Table/Query (lista proveniente de otra tabla)
#
# - **Limit to List**
#   - Evita que el usuario escriba valores no incluidos en la lista.
#
# - **Allow Multiple Values**
#   - Permite seleccionar más de un valor (útil en ciertos escenarios).
#
# Todos estos pueden revisarse con **F1** dentro de Access para ver documentación detallada.
#
# ---
#
# ## 🎯 Conclusión
# El Lookup Wizard solo construye la estructura inicial.
# La configuración real y editable vive en la **pestaña Lookup**, donde puedes modificar la lista mediante *Row Source* y otros parámetros. Esto permite:
#
# - Ajustar opciones sin reconstruir el wizard
# - Mantener consistencia
# - Evolucionar la lista con el tiempo
# - Controlar mejor cómo los usuarios capturan los datos

# %% [markdown]
# ## **Uso de la Columna *Description* para Documentar Campos en Access**
#
# En esta lección se introduce una práctica poco utilizada pero extremadamente valiosa en el diseño de bases de datos: **añadir descripciones a los campos** dentro de la vista de diseño. Aunque Access marca esta columna como *opcional*, es una herramienta clave para mantener una base de datos clara, comprensible y sostenible especialmente cuando varias personas trabajan en ella.
#
# ### 🔑 Idea principal
# El campo **Description** permite documentar cada columna de la tabla con notas internas. Estas notas:
# - No afectan el funcionamiento de la tabla.
# - No aparecen en formularios ni reportes.
# - Sirven como documentación técnica.
# - Ayudan a otros desarrolladores (o a ti mismo en el futuro) a entender el propósito de cada campo.
#
# ---
#
# ### 🟦 ¿Qué es la columna Description?
# En **Design View**, junto a *Field Name* y *Data Type*, aparece:
#
# | Field Name | Data Type | Description |
# |------------|-----------|-------------|
#
# El contenido de **Description** sirve como comentario o anotación sobre:
# - Qué representa el campo.
# - Cómo debe usarse.
# - Reglas especiales (ej. requerimientos, formato esperado).
# - Información útil para mantenimiento o futuras modificaciones.
#
# ---
#
# ### 🧩 Ejemplos aplicados de la lección
# El instructor muestra cómo documentar campos clave:
#
# - **StudentID**
#   `Automatically numbers each record`
#
# - **State**
#   `Requires two alpha characters`
#
# - **Major**
#   `Select from dropdown menu (Lookup Wizard)`
#
# Estos mensajes ayudan a entender rápidamente:
# - La lógica de cada campo
# - Restricciones aplicadas
# - Cómo se espera que se usen los datos
#
# ---
#
# ### 🧠 ¿Por qué es tan importante documentar campos?
# Porque evita problemas como:
# - Desconocer reglas de validación aplicadas hace meses o años.
# - Olvidar por qué se usó cierto tipo de dato.
# - No saber cómo fue diseñado el dropdown o máscara.
# - Dificultad para mantener o depurar tablas heredadas de otros usuarios.
#
# Es una forma de “comunicación interna” dentro de la base de datos.
#
# ---
#
# ### 🧪 Actividad recomendada
# Agregar descripciones útiles a tus campos existentes:
#
# - `StudentID` → “Primary identifier, auto-numbered”
# - `FirstName` → “Student’s given name”
# - `LastName` → “Student’s family name”
# - `State` → “Two-letter uppercase abbreviation”
# - `Major` → “Choose from dropdown list”
# - `PhoneNumber` → “Formatted using input mask”
#
# No necesitas describir lo obvio, pero sí lo que ayuda a otros a entender la intención del diseño.
#
# ---
#
# ### 🎯 Conclusión
# La columna **Description** es un recurso simple pero muy poderoso para documentar tus tablas.
# Dejar notas claras evita confusiones, facilita el mantenimiento y mejora la colaboración entre varios usuarios o equipos.
# Es una buena práctica profesional que debería incorporarse en cada tabla bien diseñada.

# %% [markdown]
# ## Tabla de Validation Rule y Validation Text en Access
#
# | Propósito / Campo | Validation Rule | Validation Text | Descripción |
# |-------------------|-----------------|-----------------|-------------|
# | **Estado obligatorio de 2 letras** | `Len([State]) = 2` | "Debe ingresar exactamente dos letras." | Asegura abreviaturas correctas (UT, CA, TX). |
# | **Fecha no puede ser futura** | `<= Date()` | "La fecha no puede ser mayor a hoy." | Evita capturas erróneas en fechas. |
# | **Edad mínima 18 años** | `>= 18` | "Debe ser mayor o igual a 18 años." | Valida edades legales o académicas. |
# | **Nombre sin números** | `Not Like "*[0-9]*"` | "El nombre no puede contener números." | Evita combinaciones incorrectas como A1berto. |
# | **Correo electrónico válido (simple)** | `Like "*@*.*"` | "Ingrese un correo válido." | Verifica estructura básica de un email. |
# | **Créditos entre 1 y 30** | `Between 1 And 30` | "Los créditos deben estar entre 1 y 30." | Asegura rangos válidos en valores académicos. |
# | **Campo no puede quedar vacío** | `Is Not Null` | "Este campo es obligatorio." | Similar a Required pero más estricto. |
# | **Solo letras permitidas** | `Like "[A-Za-z]*"` | "Solo se permiten letras." | Evita números y símbolos. |
# | **GPA entre 0 y 4.0** | `Between 0 And 4` | "El GPA debe ser entre 0 y 4.0." | Controla rangos de calificaciones. |
# | **Graduación ≥ fecha de inscripción** | `[GraduationDate] >= [DateEnrolled]` | "La graduación no puede ser antes de la inscripción." | Reglas entre campos (tabla completa). |

# %% [markdown]
# ## **Primary Key en Access (Fundamento para Relaciones entre Tablas)**
#
# En esta lección se presenta el concepto clave para construir relaciones dentro de Access: la **Primary Key**. Esta clave es esencial para identificar registros de manera única dentro de una tabla y es el punto de conexión para enlazar tablas entre sí.
#
# ### 🧠 ¿Qué es una Primary Key?
# Es un campo (o combinación de campos) cuyo valor:
# - **Debe ser único**, no se puede repetir.
# - **No puede quedar vacío** (no admite Null).
# - **Identifica un registro de forma inequívoca**.
#
# Access muestra una pequeña llave 🔑 junto al campo marcado como Primary Key.
#
# ---
#
# ## 🪝 ¿Por qué es tan importante?
# La Primary Key es el **fundamento de las relaciones** entre tablas.
# Cuando relacionas dos tablas:
#
# - La tabla principal aporta su **Primary Key**.
# - La tabla relacionada almacena ese valor como **Foreign Key**.
#
# Ejemplo clásico (mostrado en Northwind):
# - **Customers.CustomerID** → Primary Key
# - **Orders.CustomerID** → Foreign Key que apunta a Customers
#
# Esto permite:
# - Unir registros entre tablas
# - Crear subdatasheets (+)
# - Poner filtros relacionados
# - Construir consultas potentes
# - Mantener integridad referencial
#
# ---
#
# ## 🗂️ Ejemplo real: Northwind
# El instructor muestra dos tablas:
#
# - **Customers**
#   - Primary Key: `CustomerID`
# - **Orders**
#   - Primary Key: `OrderID`
#   - Contiene un campo `CustomerID` que se relaciona con la tabla Customers
#
# La relación se crea arrastrando: Customers.CustomerID  →  Orders.CustomerID
#
# Así Access entiende qué pedidos pertenecen a qué cliente.
#
# ---
#
# ## 🧱 Aplicación en la base Student Courses
# En la tabla `TBL_Students` ya existe un campo:
#
# - **StudentID**
#   Creado inicialmente por Access como "ID" y renombrado después.
#
# Este campo:
# - Es Primary Key
# - Será único por estudiante
# - Permitirá relacionar la tabla con:
#   - Cursos inscritos
#   - Calificaciones
#   - Historial académico
#   - Pagos u otros módulos
#
# Acciones disponibles:
# - Clic derecho sobre un campo → **Primary Key**
# - También se activa/desactiva desde el botón de la cinta superior
#
# ---
#
# ## 🚫 ¿Qué NO puede ser Primary Key?
# Campos que pueden repetirse, por ejemplo:
# - FirstName
# - LastName
# - State
# - Major
# - PhoneNumber
#
# Estos valores no garantizan unicidad; por eso se usa un **ID numérico o autonumérico**.
#
# ---
#
# ## 🧪 Cómo validar que todo funciona
# En **Design View**:
# 1. Selecciona un campo.
# 2. Haz clic en **Primary Key**.
# 3. Intenta guardar valores duplicados en Datasheet View:
#    - Access impedirá la duplicación.
#    - Muestra un mensaje de error si se intenta repetir la clave.
#
# Esto confirma que la PK está activa.
#
# ---
#
# ## 🎯 Conclusión
# La **Primary Key** es el elemento central para:
# - Identificar registros
# - Garantizar la integridad de datos
# - Construir relaciones entre tablas
# - Permitir consultas y reportes robustos
#
# Sin una Primary Key correcta, no se pueden establecer relaciones confiables en Access ni construir una base de datos profesional.
#
# ``

# %% [markdown]
# ## **Ingresar Registros y Probar la Tabla Construida en Access**
#
# En esta lección se muestra cómo empezar a **capturar registros reales** en la tabla `TBL_Students` para probar que todos los campos, propiedades y formatos funcionan correctamente. El objetivo es validar que la estructura diseñada produce una experiencia de captura consistente, controlada y sin errores.
#
# ### 🔑 Idea principal
# Después de configurar:
# - campos,
# - tipos de datos,
# - propiedades (Required, Default Value, Field Size, Input Mask, Caption),
# - lookup lists,
# - y Primary Key,
#
# ahora toca **probar la tabla con datos reales** para confirmar que todo funciona tal como lo diseñaste.
#
# ---
#
# ## 🟦 1. Cambiar a Datasheet View e ingresar un registro
# En **Datasheet View**, ya puedes comenzar a escribir información en cada campo.
#
# Ejemplo de registro ingresado en la lección:
#
# - **FirstName:** Joe
# - **LastName:** Thornton
# - **Address:** (dato ingresado manualmente)
# - **City:** San Jose
# - **PostalCode:** 94589 (o cualquier dato válido)
# - **State:** CA → la máscara personalizada convierte automáticamente a **mayúsculas** y limita a 2 caracteres
# - **PhoneNumber:** 555‑555‑5555 → formateado automáticamente por el **Input Mask**
# - **Active:** ✔ (se puede alternar con la barra espaciadora)
# - **DateEnrolled:** se llena automáticamente con la fecha actual por el **Default Value = Date()**
# - **GraduationDate:** aún sin definir
# - **Advisor:** Peter
# - **Major:** seleccionado desde la lista desplegable creada por Lookup Wizard
#
# Cada propiedad creada anteriormente se pone a prueba aquí.
#
# ---
#
# ## 🟩 2. Sobre el AutoNumber del StudentID
# El campo `StudentID` es un **AutoNumber**, por lo que:
# - Access asigna automáticamente un número nuevo para cada registro.
# - Si se elimina un registro, **ese número no se vuelve a usar**.
#   - Por ejemplo, si alguna vez existió el 1, 2 y 3, pero se borraron, el siguiente registro podría empezar en 4.
#
# Esto es normal y esperado.
# Si deseas controlar manualmente los IDs, tendrías que usar un campo Text o Number en lugar de AutoNumber.
#
# ---
#
# ## 🟧 3. Por qué es importante esta fase
# Ingresar registros te permite verificar:
#
# - ¿Las máscaras funcionan?
# - ¿Los campos obligatorios detienen registros vacíos?
# - ¿El Default Value aparece automáticamente?
# - ¿Los Lookup Lists muestran la lista correcta?
# - ¿Los tamaños de texto son suficientes?
# - ¿La Primary Key se asigna sin problemas?
#
# Si algo no funciona como esperabas, puedes volver a **Design View** y ajustar:
#
# - Field Size
# - Input Mask
# - Default Value
# - Required
# - Lookup Wizard
# - Validation Rules
#
# ---
#
# ## 🧪 4. Actividad recomendada
# Ingresa varios registros ficticios con nombres, direcciones y majors diferentes.
# Observa si:
#
# - El flujo de captura te resulta cómodo
# - Cualquier campo necesita ajustes
# - Algún formato no se comporta como lo imaginaste
#
# Este es el momento ideal para modificar y perfeccionar la estructura antes de crear más tablas o relaciones.
#
# ---
#
# ## 🎯 Conclusión
# La tabla está lista y funcional. Ingresar datos reales permite confirmar que cada propiedad configurada contribuye a una captura limpia, consistente y profesional. Este paso es crítico antes de avanzar a crear nuevas tablas o establecer relaciones dentro de la base *Student Courses*.
