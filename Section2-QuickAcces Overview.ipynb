# %% [markdown]
# ## 🗂 Resumen: File Tab en Microsoft Access
#
# El **File Tab** en Access funciona como en Word o Excel, pero con particularidades propias.
# El instructor quiere enseñar:
#
# ### 🔑 ¿Qué opciones importantes contiene?
# - **New**: Crear una nueva base de datos.
# - **Open**: Abrir bases existentes.
# - **Save As**: Guardar con otro nombre o crear una copia.
# - **Print**: Vista previa e impresión de tablas o elementos seleccionados.
# - **Close**: Cerrar la base de datos (no Access).
# - **Account**: Opciones de cuenta de Office 365.
# - **Options**: Configuración general de Access.
#
# ### 🖨 Notas clave sobre la impresión
# - La impresión funciona **distinto a Word o Excel**.
# - La opción **Print Preview** depende del **objeto seleccionado**, aunque no esté abierto.
# - En la vista previa, el **Ribbon cambia** y aparece la pestaña “Print Preview”.
# - Al cerrar esa vista, Access regresa al Ribbon normal.
#
# ### ⚙️ Access Options
# - Aquí se puede **personalizar la experiencia de uso**.
# - Es similar al área de opciones en otros programas de Office.
#
# ### 🎯 Finalidad principal del File Tab
# - Gestionar archivos, impresión y configuración general de Access.
# - Familiarizar al usuario con un área que funciona parecido a otros programas, pero con **comportamientos únicos** en Access.

# %% [markdown]
# ## 🔒 Resumen: Advertencias de Seguridad al Abrir Bases de Datos en Access
#
# Al abrir una base de datos de Access descargada, enviada por correo o tomada de una ubicación externa, es común recibir una **Security Warning** indicando que *active content* ha sido deshabilitado.
#
# ### 🔑 ¿Qué es el “active content”?
# - **Macros**
# - **Código VBA**
# - **Datos vinculados** (Excel, SharePoint, otros servidores o bases externas)
#
# Estos elementos **no funcionarán** hasta que el usuario los habilite.
#
# ### ⚠️ ¿Por qué aparece la advertencia?
# - Para evitar ejecutar contenido potencialmente peligroso si el archivo proviene de una fuente desconocida.
# - Access bloquea automáticamente código o conexiones por seguridad.
#
# ### 🟢 ¿Cuándo habilitar el contenido?
# - Cuando **confías en la fuente** (compañero, repositorio oficial, material del curso).
# - Ejemplo del curso: la base **Northwind** requiere habilitar contenido porque contiene código VBA y datos vinculados.
#
# ### 🖱 ¿Qué ocurre al habilitarlo?
# - Access ejecuta el código incorporado.
# - En el caso de Northwind:
#   - Se muestra una **pantalla de bienvenida**.
#   - Se abre un **switchboard** o menú principal (se puede cerrar por ahora).
#
# ### 🎯 Finalidad principal de esta lección
# - Identificar y entender la **Security Warning**.
# - Saber **cuándo es seguro habilitar el contenido**.
# - Reconocer que muchas bases de datos reales dependen de macros, VBA y vínculos externos para funcionar correctamente.
